# %%
# !pip install python-dotenv
# !pip install openai
# Out:
# Requirement already satisfied: python-dotenv in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (1.0.0)
# Requirement already satisfied: openai in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from openai) (0.26.0)
# Requirement already satisfied: sniffio in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from openai) (1.2.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from openai) (2.5.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from openai) (1.9.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from openai) (4.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from openai) (3.5.0)
# Requirement already satisfied: tqdm>4 in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from openai) (4.64.1)
# Requirement already satisfied: idna>=2.8 in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai) (3.3)
# Requirement already satisfied: httpcore==1.* in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: certifi in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai) (2022.9.24)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (2.14.6)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)

# %% [markdown]
# # Getting data from Mergeflow's API

# %%
import requests
import json
import os
from dotenv import load_dotenv # stores API keys for OpenAI and Mergeflow 

load_dotenv()  # Load variables from .env file
mergeflow_api_key = os.getenv('MERGEFLOW_API_KEY') # Assign Mergeflow API

# the API call
query = 'factory automation' # topic is factory automation
dataset = '&q=*%5bfundingcompany%7cfundingproject%7cfundingorganization%5d&sp=2572' # access dataset from mergeflow - in this case venture capital investments
rows = str(10) # first 10 docs only

# in the url below, replace "fw" by your user name. You can see your user name at mergeflow.net
# -> Account -> the string in angle brackets
url = 'https://mergeflow.net/api/v1/ferdinandk/search/getContent?q=' + query + dataset + '&rows=' + rows

# Define the headers to be sent with the request
headers = {
    'MergeflowNet-Api-Auth-Key': mergeflow_api_key
}

# Get and print the response
response = requests.post(url, headers=headers)

mergeflow_docs = []

# Check the response status code and content
if response.status_code == 200:
    mergeflow_response_json = response.json()
    
    # Pretty-print the JSON response -- useful to understand what the JSON looks like
    #pretty_json = json.dumps(mergeflow_response_json, indent=4)
    #print(pretty_json)
    
    # get title, URL, date, and content
    for document in mergeflow_response_json['Documents']:
        current_doc = {
            'title': document['Title'],
            'date': document['Date'],
            'url': document['Url'],
            'content': document['Content']
        }
        
        mergeflow_docs.append(current_doc)
        #print(content)        

    print('Found ' + str(len(mergeflow_docs)) + ' documents.')

else:
    print('Request failed with status code:', response.status_code)
    print(response.text)  # Print the response text
# Out:
# Found 10 documents.

# %%
import openai
import os
import requests
import json

openai.api_key = os.getenv('OPENAI_API_KEY')

summary_list = []

system_prompt_summary = f"""
You are a highly qualified academic scholar who has much experience in communicating your results to a broad audience. You are able to extract the most important aspects of texts, compress them and rephrase them in a comprehensible way.
"""

for doc in mergeflow_docs:
    user_prompt_summary = f"""
    Consider the text below, delimited by ```, in the area of {query}:
    ```
    {doc['content']}
    ```
    Please summarize the finding of the text in at most 500 words, and clearly cite the source at the end.
    """
    completion_summary = openai.chat.completions.create(
        model="gpt-3.5-turbo-0125",
        messages=[
            {"role": "system", "content": system_prompt_summary},
            {"role": "user", "content": user_prompt_summary}
        ],
        temperature=0.7,
        max_tokens=2000,
        top_p=0.95,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None
    )

    summary_list.append(completion_summary.choices[0].message.content)
    print(completion_summary.choices[0].message.content)
    print("\n---\n")


print(summary_list)
print("\n----------------------------------------------\n----------------------------------------------\n")
# Out:
# Aniai, a New York City-based robotic company specializing in kitchen solutions, recently secured $12 million in Pre-Series A funding. The funding round was led by InterVest, with contributions from SV Investment, Ignite Innovation from the UK, and existing investor Capstone Partners. The company plans to utilize these funds to establish its first manufacturing facility, named Factory One, in South Korea. This facility will play a crucial role in ensuring stable production and efficient supply chain management for Aniai's flagship product, the Alpha Grill. The move aligns with the company's strategic expansion efforts in North America and globally.
#
# Founded in 2020 and under the leadership of CEO Gunpil Hwang, Aniai focuses on developing robotic solutions for cooking hamburgers. The Alpha Grill, their key product, utilizes robotics to cook hamburgers efficiently. It features a double-sided grill capable of cooking up to eight patties simultaneously or 200 patties per hour. By automating tasks such as pressing and flipping patties, the Alpha Grill enables restaurant brands to enhance operational efficiency, reduce cooking time, and alleviate labor-intensive processes for employees.
#
# Gunpil Hwang expressed his excitement about the funding, emphasizing how it will support Aniai's mission to enhance kitchen productivity through robotics and automation. The capital infusion will also aid in scaling up production to meet current and future demand. In addition to expanding production capacity, Aniai plans to enhance its robotic solutions by integrating advanced, cloud-based AI software into the Alpha Grill. This upgrade aims to further improve the capabilities and performance of the product, benefiting both new and existing Aniai customers.
#
# In conclusion, Aniai's successful $12 million Pre-Series A funding round, led by InterVest, marks a significant milestone for the company as it prepares to establish its manufacturing facility in South Korea and enhance its flagship product, the Alpha Grill, with advanced AI technology. This strategic move positions Aniai for continued growth in the competitive market of robotic kitchen solutions.
#
# Source: Aniai Closes $12M Pre-Series A Funding, Source: [Insert full source information here]
#
# ---
#
# Virdee, a company based in Austin, Texas, specializing in guest experience technology and check-in automation, recently secured $12.4 million in Series A funding. This funding round was led by Moneta Ventures, with contributions from Silverton Partners, Koch Real Estate Investments, Alumni Ventures, DJR Advisors, Capital Factory, and other partners. As part of this investment, Brent Kelton from Moneta Ventures joined Virdee's board. This funding round follows previous financing rounds, including a Seed financing led by Silverton Partners in February 2022 and an angel investment in 2020 led by Rajiv Trivedi, the former President of La Quinta Inns & Suites.
#
# Founded in 2020 by Branigan Mulcahy and Nadav Cornberg, Virdee offers a software platform for the hospitality industry that includes guest experience technology and check-in automation. Their platform offers various options such as Web, app, kiosk, and SDK, connecting guests and hotels through digital applications and AI to automate front desk transactions. Virdee's solution can be integrated into existing digital experiences of hotels, enhancing guest experiences, reducing wait times, and enabling front desk staff to focus on guest relationships.
#
# One of the key features of Virdee's platform is its contactless hotel check-in experience, which is compatible with various systems, including web, app, and kiosk-based systems. The platform includes features like Virdee Identity, upgrades and upsells, Remote Assistance, and supports 100% of guest check-ins. Notably, Virdee's platform is already in use at four of the largest casino hotels in Las Vegas and several other major hotel brands.
#
# In summary, Virdee's recent Series A funding of $12.4 million, led by Moneta Ventures, reflects a growing interest in the company's innovative guest experience technology and check-in automation platform within the hospitality industry. The company's ability to enhance guest experiences, streamline operations, and adapt to various hotel systems positions them as a key player in the evolving landscape of hospitality technology.
#
# Source: Virdee Closes $12.4M in Series A Funding. Retrieved from [source URL]
#
# ---
#
# Cellares, an integrated development and manufacturing organization (IDMO) based in South San Francisco, recently secured $255 million in Series C funding. The funding round was led by Koch Disruptive Technologies, with participation from Bristol Myers Squibb, DFJ Growth, Willett Advisors, and existing investors Eclipse, Decheng Capital, and 8VC. As part of the financing, David Mauney from Koch Disruptive Technologies will be joining Cellares' board of directors.
#
# Led by CEO Fabian Gerlinghaus, Cellares focuses on developing and operating integrated technologies for cell therapy manufacturing to expedite the availability of life-saving cell therapies. One of their key innovations is the Cell Shuttle, a versatile platform that streamlines the entire cell therapy manufacturing process with end-to-end automation, allowing for walk-away operation.
#
# Currently, Cellares operates two Smart Factories in the US, with plans for a third one in the pipeline. The first Smart Factory, situated in South San Francisco, is primarily used for preclinical process development and transitioning manual processes onto the Cell Shuttle for existing partners. This facility is expected to be cGMP-ready by the first half of 2024.
#
# Additionally, Cellares is developing a 118,000 sq. ft. IDMO Smart Factory in Bridgewater, New Jersey, which will have the capacity to produce 40,000 cell therapy batches annually. This New Jersey site is projected to be cGMP-ready by the latter half of 2024. While the company can support clinical trials in Europe from its US Smart Factories, it is also set to construct its first IDMO Smart Factory in Europe in 2024.
#
# In essence, Cellares' recent funding success and expansion plans highlight their commitment to advancing cell therapy manufacturing through cutting-edge technology and automated processes. Their innovative approach aims to accelerate the development and delivery of life-saving cell therapies to patients in need.
#
# Source: Cellares Raises $255M in Series C Funding
#
# ---
#
# Terabase Energy, a leading provider of digital and automation solutions for solar power plants, has secured $25 million in new financing to support the commercial scale-up of their Terafab construction automation system. The funding round was led by Fifth Wall, a prominent asset manager focused on improving and decarbonizing the built environment, with participation from EDP Ventures and other existing investors. The Terafab system is described as the world's first automated, digital field factory for constructing solar power plants, aiming to revolutionize the solar industry by automating construction processes.
#
# Anastasia Istratova, a Principal at Fifth Wall, expressed excitement about supporting Terabase's vision of transforming the solar industry through innovative automation technologies. The company's mission aligns with Fifth Wall's commitment to investing in technologies that drive the scale-up of renewable energy infrastructure. Luis Manuel, a Board Member at EDP Ventures, highlighted Terabase's role in addressing the renewable energy sector's need to scale rapidly and meet ambitious growth targets, emphasizing the importance of digitization and automation in increasing the industry's capacity to build PV power plants efficiently.
#
# Terabase Energy's CEO and Co-Founder, Matt Campbell, emphasized the significance of the financial backing received, noting the industry enthusiasm for the company's mission. The funding will enable Terabase to expedite the scaling of Terafab production and meet the growing demand effectively as they deploy the system. In addition to construction automation, Terabase Energy is also experiencing momentum with its software products, including Construct, a construction management software, and PlantPredict, a solar energy modeling tool that has surpassed 2.8 terawatts of simulations across thousands of projects.
#
# The company's platform aims to reduce costs and accelerate the deployment of utility-scale solar projects through construction automation and software solutions. Terabase's suite of products, which includes PlantPredict, Construct, Terafab construction automation, and power plant control solutions, enables rapid deployment of solar plants at competitive costs. The company also supports the production of green hydrogen with PV in the future, showcasing a commitment to sustainable energy solutions.
#
# Fifth Wall, the leading asset manager backing Terabase's financing round, is dedicated to improving and decarbonizing the built world. With a significant capital raised globally and a diverse group of strategic limited partners, Fifth Wall collaborates with portfolio companies to drive emissions reduction, enhance efficiency, and maximize returns in the built environment sector. EDP Ventures, the corporate venture capital arm of global energy company EDP, focuses on investing in Energy and Climate Tech startups to support innovation in the energy industry.
#
# In summary, Terabase Energy's recent financing round led by Fifth Wall, with participation from EDP Ventures and other investors, will enable the company to accelerate the commercial scale-up of their Terafab construction automation system, advancing their mission to revolutionize the solar industry through digitization, automation, and software solutions.
#
# Source: Business Wire
#
# ---
# The Numbers Station, a company based in Menlo Park, California, has recently secured $17.5 million in funding through a series A round and seed funding. This funding was led by Madrona, a prominent venture capital firm. The company specializes in an intelligent data stack automation platform, which aims to streamline data work processes for users. The series A funding specifically amounted to $12.5 million and was significant due to the participation of other key investors such as Norwest Venture Partners, Factory, and notable angel investor Jeff Hammerbacher, who is a co-founder of Cloudera. The total capital raised by Numbers Station now stands at $17.5 million, combining the recent series A round with a prior $5 million seed round. The technology utilized by Numbers Station is based on foundation model technology developed at the Stanford AI lab. This technology allows data workers to more efficiently generate insights by automating repetitive data tasks, initially focusing on data transformation work.
#
# Source: Numbers Station Raises $17.5 Million. MENLO PARK, CA. Retrieved from [insert source here]
#
# ---
#
# The text discusses a company called Numbers Station based in Menlo Park, CA, which recently raised $17.5 million in funding. The funding included a $12.5 million Series A round led by Madrona, with participation from Norwest Venture Partners, Factory, and notable angel investors like Jeff Hammerbacher. This funding round followed a previous $5 million seed round, bringing the total capital raised to $17.5 million. As part of the funding, Tim Porter from Madrona joined the Numbers Station board.
#
# Numbers Station, founded in 2021 by CEO Chris Aberger, offers an intelligent data stack automation platform that utilizes proprietary foundation model technology. This platform allows data practitioners of all skill levels to automate workflows in the modern data stack using natural language. Users can perform tasks ranging from basic formatting to complex operations like entity resolution or extraction. The platform enables individuals to leverage AI for data transformation, connect to their data warehouse, prototype intelligent data transformations using a conversational interface, and deploy pipelines back into the data warehouse. These automated pipelines can be applied to various business use cases across different departments.
#
# The platform, developed based on research from the Stanford AI Lab by Chief Scientist and Co-founder Ines Chami, along with the founding team, works with any foundation model in combination with proprietary foundation models and algorithms tailored for managing data-intensive tasks. Numbers Station is currently available in private beta.
#
# In summary, Numbers Station has secured $17.5 million in funding, with a focus on providing an intelligent data stack automation platform that empowers users to automate data workflows using natural language and AI technology. The platform's capabilities span from basic data tasks to complex operations, catering to users of varying skill levels. The company's foundation model technology, developed based on research from the Stanford AI Lab, enables efficient management of data-intensive tasks.
#
# Source: Original text retrieved from undisclosed source in the area of factory automation.
#
# ---
#
# Numbers Station, an intelligent data stack automation platform, has secured $17.5 million in funding, with a $12.5 million series A round led by Madrona. The platform aims to democratize access to AI by automating tedious data transformation work using foundation model technology developed at the Stanford AI lab. By enabling data workers to generate insights rapidly without the need for coding or AI expertise, Numbers Station empowers users to work with messy and complex data through natural language interactions with intelligent foundation models.
#
# The platform covers a wide range of data tasks, from basic formatting to complex tasks like entity resolution and extraction. It allows users to connect to their data warehouse, prototype intelligent data transformations through a conversational interface, and deploy pipelines back into their data warehouse. This capability enables customers to apply automated pipelines to various business use cases across departments, facilitating quicker access to insights and enhancing decision-making processes within organizations.
#
# Numbers Station's approach has garnered praise for its potential impact on enterprises, particularly in streamlining data preparation and transformation processes. By offering a solution that simplifies setting up data pipelines, cleaning data, and performing various data-related tasks, Numbers Station aims to lower the technical barriers associated with managing data-intensive workflows. The platform's integration of foundation models into the modern data stack resonates with industry experts who recognize its potential to revolutionize work processes in handling messy data.
#
# The Numbers Station team, which includes Chief Scientist and Co-founder Ines Chami, along with other founding members, has developed proprietary foundation models and algorithms to address data-intensive tasks efficiently. The platform's self-service nature and utilization of natural language interfaces cater to users of all skill levels, making it accessible for data practitioners to automate workflows seamlessly within the modern data stack.
#
# In conclusion, Numbers Station's innovative approach to data automation, coupled with its foundation model technology, presents a significant opportunity for enterprises to enhance their data analytics capabilities. By bridging the gap between data engineers and data teams, the platform offers a streamlined solution for automating data-intensive workflows and deriving valuable insights at a rapid pace.
#
# Source: Numbers Station Raises $17.5 million for AI-powered Data Stack Automation | Business Wire.
#
# ---
#
# Worlds Enterprises, a company based in Dallas, Texas, has secured $21 million in Series A1 funding. This funding round was led by Moneta Ventures, with participation from other key investors such as Align Capital, Green Park & Golf Ventures, Chevron Technology Ventures, Piva Capital, PerotJain, and Capital Factory. The company, under the leadership of CEO Dave Copps and President Chris Rohde, specializes in providing a 4D infrastructure for constructing the Industrial Metaverse. This innovative platform integrates AI-based automation directly into the operational processes of large industrial firms.
#
# Worlds' unique approach involves converting everyday activities and processes into a live data stream, enabling organizations to measure, analyze, and unlock significant untapped value. The company's primary focus areas include sectors within the supply chain such as manufacturing, distribution, logistics, transportation, energy, and national defense. Since its market launch in August 2021, Worlds has already gained traction among major industrial players like Chevron, PETRONAS, and Hillwood Development Company.
#
# The funding secured by Worlds is expected to fuel further development and expansion of its 4D infrastructure for the Industrial Metaverse. By leveraging cutting-edge technologies and AI-driven solutions, Worlds aims to revolutionize the way industrial operations are managed and optimized. With a strong investor backing and a growing client base comprising prominent industry leaders, Worlds is poised to make a significant impact in the realm of factory automation and industrial digitization.
#
# Source: Original text excerpt from a news article in the field of factory automation.
#
# ---
#
# Worlds Enterprises, Inc. has successfully secured a $21.2 million Series A1 funding round led by Moneta Ventures, with participation from key investors such as Align Capital, Green Park & Golf Ventures, Chevron Technology Ventures, and others. This funding will support the company's AI platform and help in expanding partnerships to further the adoption of its Industrial Metaverse technology by industrial companies. The platform developed by Worlds integrates AI-based automation into the operations of large industrial companies by creating a digital twin that brings together IoT sensors, people, and processes. This enables organizations to better measure and reimagine their operations in ways that were previously unattainable.
#
# CEO Dave Copps emphasizes the importance of digital transformation and the convergence of digital and physical worlds in reshaping how businesses operate. Worlds stands out in the market by providing a comprehensive solution that addresses the need for a unified platform amidst various fragmented offerings. The company has already gained traction with major industrial players like Chevron, PETRONAS, and Hillwood Development Company, experiencing significant growth and expanding its client base.
#
# Moneta Ventures recognizes Worlds' unique 4D infrastructure for the Industrial Metaverse as a game-changer in the industry, offering ease, speed, and cost-effectiveness for clients. Align Capital also praises Worlds' leadership team and innovative technology that has the potential to revolutionize how industrial companies automate and optimize their operations. Worlds focuses on sectors such as manufacturing, distribution, logistics, transportation, energy, and national defense, offering a platform that converts everyday processes into valuable data streams for analysis and improvement.
#
# In summary, Worlds Enterprises, Inc. has received substantial funding to scale its Industrial Metaverse platform, which integrates AI-based automation into the operations of large industrial companies. The company's unique approach has garnered attention from investors and major clients, positioning Worlds as a key player in reshaping how industrial businesses operate in the digital age.
#
# Source: Business Wire. "Worlds Announces $21 Million Series A1 Funding Round to Scale Industrial Metaverse Platform." Retrieved from https://www.businesswire.com/.
#
# ---
# The text discusses Software Defined Automation, a company that has recently raised $10 million in seed funding. Insight Partners led the funding round, with participation from Baukunst VC, Fly Ventures, and First Momentum. As a result of the transaction, Jon Rosenbaum from Insight Partners and Axel Bichara from Baukunst will be joining Software Defined Automation's Board of Directors.
#
# Software Defined Automation specializes in innovating factory automation through its Industrial-Control-as-a-Service (ICaaS) offering. This service involves cloud-based management of existing Programmable Logic Controllers (PLCs) known as TechOps, Git-enabled PLC code versioning and collaboration under DevOps, and virtualization of PLCs on edge servers referred to as Virtual PLC. By integrating these technologies, Software Defined Automation aims to dismantle proprietary silos in control technology stacks and facilitate the adoption of API-based modern microservices architecture.
#
# The company is based in both Boston, US and Munich, Germany, highlighting its international presence and commitment to advancing factory automation technologies.
#
# In conclusion, Software Defined Automation's successful seed funding round underscores the growing interest and investment in innovative solutions for factory automation. The company's focus on leveraging cloud-based management, code versioning, and virtualization technologies to enhance control systems signifies a shift towards more agile and interconnected automation processes.
#
# Source: Software Defined Automation Raises $10M in Seed Funding
#
# ---
#
# ["Aniai, a New York City-based robotic company specializing in kitchen solutions, recently secured $12 million in Pre-Series A funding. The funding round was led by InterVest, with contributions from SV Investment, Ignite Innovation from the UK, and existing investor Capstone Partners. The company plans to utilize these funds to establish its first manufacturing facility, named Factory One, in South Korea. This facility will play a crucial role in ensuring stable production and efficient supply chain management for Aniai's flagship product, the Alpha Grill. The move aligns with the company's strategic expansion efforts in North America and globally.\n\nFounded in 2020 and under the leadership of CEO Gunpil Hwang, Aniai focuses on developing robotic solutions for cooking hamburgers. The Alpha Grill, their key product, utilizes robotics to cook hamburgers efficiently. It features a double-sided grill capable of cooking up to eight patties simultaneously or 200 patties per hour. By automating tasks such as pressing and flipping patties, the Alpha Grill enables restaurant brands to enhance operational efficiency, reduce cooking time, and alleviate labor-intensive processes for employees.\n\nGunpil Hwang expressed his excitement about the funding, emphasizing how it will support Aniai's mission to enhance kitchen productivity through robotics and automation. The capital infusion will also aid in scaling up production to meet current and future demand. In addition to expanding production capacity, Aniai plans to enhance its robotic solutions by integrating advanced, cloud-based AI software into the Alpha Grill. This upgrade aims to further improve the capabilities and performance of the product, benefiting both new and existing Aniai customers.\n\nIn conclusion, Aniai's successful $12 million Pre-Series A funding round, led by InterVest, marks a significant milestone for the company as it prepares to establish its manufacturing facility in South Korea and enhance its flagship product, the Alpha Grill, with advanced AI technology. This strategic move positions Aniai for continued growth in the competitive market of robotic kitchen solutions.\n\nSource: Aniai Closes $12M Pre-Series A Funding, Source: [Insert full source information here]", "Virdee, a company based in Austin, Texas, specializing in guest experience technology and check-in automation, recently secured $12.4 million in Series A funding. This funding round was led by Moneta Ventures, with contributions from Silverton Partners, Koch Real Estate Investments, Alumni Ventures, DJR Advisors, Capital Factory, and other partners. As part of this investment, Brent Kelton from Moneta Ventures joined Virdee's board. This funding round follows previous financing rounds, including a Seed financing led by Silverton Partners in February 2022 and an angel investment in 2020 led by Rajiv Trivedi, the former President of La Quinta Inns & Suites.\n\nFounded in 2020 by Branigan Mulcahy and Nadav Cornberg, Virdee offers a software platform for the hospitality industry that includes guest experience technology and check-in automation. Their platform offers various options such as Web, app, kiosk, and SDK, connecting guests and hotels through digital applications and AI to automate front desk transactions. Virdee's solution can be integrated into existing digital experiences of hotels, enhancing guest experiences, reducing wait times, and enabling front desk staff to focus on guest relationships.\n\nOne of the key features of Virdee's platform is its contactless hotel check-in experience, which is compatible with various systems, including web, app, and kiosk-based systems. The platform includes features like Virdee Identity, upgrades and upsells, Remote Assistance, and supports 100% of guest check-ins. Notably, Virdee's platform is already in use at four of the largest casino hotels in Las Vegas and several other major hotel brands.\n\nIn summary, Virdee's recent Series A funding of $12.4 mil ...
#
# ----------------------------------------------
# ----------------------------------------------

# %%
Problem = """Based on the provided information, the problem with the highest overall rating is:
    - Problem: Lack of seamless integration and communication between different factory automation systems and equipment.
    - User Group Impacted: Factory automation engineers and operators.
    - Specific Pain Point: Inefficient workflows, increased downtime, and suboptimal performance due to manual intervention and lack of real-time data synchronization.
    - Summary of Selection Criteria: Large target group impacted, very relevant pain point to factory automation industry and users, specific and critical issue in the industry."""

print(Problem)
# Out:
# Based on the provided information, the problem with the highest overall rating is:
#     - Problem: Lack of seamless integration and communication between different factory automation systems and equipment.
#     - User Group Impacted: Factory automation engineers and operators.
#     - Specific Pain Point: Inefficient workflows, increased downtime, and suboptimal performance due to manual intervention and lack of real-time data synchronization.
#     - Summary of Selection Criteria: Large target group impacted, very relevant pain point to factory automation industry and users, specific and critical issue in the industry.

# %% [markdown]
# # Answering questions on the results with OpenAI GPT

# %%
import openai

openai.api_key = os.getenv('OPENAI_API_KEY') # Assign OpenAI API

#System prompt (for all users)
system_prompt = f"""You are part of a brainstorming session that wants to come up with a solution to a specific problem. You customer handed you the following problem:
       
        {Problem}
        
        Now you try to figure out a solution in a brainstorming session with the Walt Disney Method: 
        It is a tool for brainstorming ideas. It involves using 3 sequential roles, namely the Dreamer, the Realist, and the Critic.
        The Dreamer: you focus on free association and brainstorming of ideas. Anything goes here. It's your chance to let your imagination run wild! Be enthusiastic and approach the task with questions such as “What would be nice?”, “What would be the optimal situation?” or “What would I wish for?” Assume that everything is possible.
        The Realist: Be realistic and decide which of your ideas are actually possible or practical. What would you need to do in the real world in order to make them happen? Take a pragmatic approach and ask which materials, which knowledge, which techniques there are with which the thoughts of the dreamer can be realised.
        The Critic: Examine proposals and its real-world implications from a more critical viewpoint. You want to make sure that your plan is as comprehensive as it can be. Every detail needs to be scrutinized and refined. It is about identifying opportunities and risks, pointing out limits and gaps, and expressing constructive and always positive criticism. Try to identify possible sources of error.
        
        Your work is highly crucial and you are responsible of coming up with the next best innovation.
        """

#Dreamer prompt (idea: come up with crazy ideas)
dreamer_solutions = {}
i = 0

user_prompt = f"""
    Consider the text below, delimited by ```, in the area of {query}:
    ```
    {summary_list}
    ```    
  
    Imagine you are the Dreamer. 
    
    Take a deep breath and work on this problem step by step. 

    
    Please develop 5 really specific ideas/visions on how this problem can be solved. The solutions should consider the following points:
    - You can let your imagination run wild and you do not care about possible limitations. It's more important the idea is new then it can really work.  
    - They should not be too general. 
    - The solution should not already exist on the market and be novel. 
    - The ideas should not be too similar to each other
    
    For the solution, please write only 40 words. It should contain the following contents:
    1) Your solution in max 3 words (title)
    2) Your solution summarized in 1 sentence
    3) Your solution from the customer perspective (customer journey: how does it work for the customer) 
    4) Why the solution is kind of new (not existing on the market)
    5) Please provide some sources of inspiration that you used from the document excerpts.


    
    """
    
completion = openai.chat.completions.create(
        model="gpt-4-0125-preview",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        temperature=0.8,
        max_tokens=2000,
        top_p=0.95,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None
    )
print(completion.choices[0].message.content) # This prints the content of the output in a more readable way
print("\n---\n")  # This adds a separator between the messages for readability
dreamer_solutions[i] = completion.choices[0].message
i += 1


#Realist prompt (idea: evaluate if it is possible and what would be needed)
realist_solutions = {}

user_prompt1 = f"""

    Imagine you are the Realist. 
    
    Take a deep breath and work on this problem step by step. 

    
    Consider the following solutions: {dreamer_solutions}.
    
    Please give me the 3 clearly speperated pieces of information for each of the solutions (in total 50 words max):
    1) "Title": Repeat the titel of the idea
    2) "Summary": 3 sentence summary of the solution
    3) "Evaluation criteria 1 detail": What would you need to do in the real world in order to make the solution happen? Answer which knowledge, which techniques there are with which the solutions can be realised. Explain in 5 sentences. 
    4) "Evaluation criteria 1": Is the solution actually possible? Answer can be 1,2 or 3 (1 = not possible, 2 = maybe possible, 3 = possible) (be the most critical person ever. Only give max. 1 of the 3 solution a 3)

    """
    

completion = openai.chat.completions.create(
model="gpt-4-0125-preview",
messages=[
{"role": "system", "content": system_prompt},
{"role": "user", "content": user_prompt1}
],
temperature=0.7,
max_tokens=2000,
top_p=0.95,
frequency_penalty=0,
presence_penalty=0,
stop=None
)

    
print(completion.choices[0].message.content) # This prints the content of the output in a more readable way
print("\n---\n")  # This adds a separator between the messages for readability
realist_solutions[0] = completion.choices[0].message


#Critics prompt (idea: evaluate if there are a lot potential sources of error)
critics_solutions = {}

user_prompt2 = f"""

    Imagine you are the Critic. 
    
    Consider the following solutions: {realist_solutions}.
    
    Take a deep breath and work on this problem step by step. 
    
    Please give me the following 4 clearly seperated pieces of information for each solution (40 words in total):
    1) "Title": Repeat the titel of the idea
    2) "Summary": 3 sentence summary of the solution
    3) "Evaluation criteria 2 details": Identify possible sources of error. Look for risks, pointing out limits and gaps, and expressing constructive criticism. Examine its real-world implications from a more critical viewpoint. You want to make sure that your plan is as comprehensive as it can be. Every detail needs to be scrutinized and refined. (1 sentence only)
    4) "Evaluation criteria 2": Does it have many potential sources of errors? Answer can be 1,2 or 3 (1 = many sources of error, 2 = some sources of error, 3 = few sources of error) (be the most critical person ever. Only give max. 1 of the 3 solution a 3) (1 sentence)
    """
    

completion = openai.chat.completions.create(
model="gpt-4-0125-preview",
messages=[
{"role": "system", "content": system_prompt},
{"role": "user", "content": user_prompt2}
],
temperature=0.7,
max_tokens=2000,
top_p=0.95,
frequency_penalty=0,
presence_penalty=0,
stop=None
)

    
print(completion.choices[0].message.content) # This prints the content of the output in a more readable way
print("\n---\n")  # This adds a separator between the messages for readability
critics_solutions[0] = completion.choices[0].message


#Summary

user_prompt3 = f"""

    Imagine you should give a summary to a high executive manager about a brainstorming session. 
    
    During the brainstorming session your team came up with the following ideas: {dreamer_solutions}. 
    For each idea you considered how feasible it is {realist_solutions}. 
    Last, you evaluated the amount of potential sources of errors: {critics_solutions} 
    
    Take a deep breath and work on this problem. 
    
    Please summarize in one paragraph for each solution, with the following content:
    
    “Name”: Solution name (5 words max)
    “Solved Problem”: 1 sentence summary of the problem that is being solved 
    “Solution”: Provide a short summary of the solution and how it works (3 sentences max)
    “Impact”: How does the solution solve the specific problem (3 sentences max)
    “Technology”: Please also give a very detailed explanation of which technology is utilized and how it is utilized. Please be very diligent in this task, imagine you are explaining it to the CTO who has a background of engineering and has to implement the solution  (5 sentences max)
    “Sources”: Please provide the specific sources of inspiration that you used from the {summary_list} (1 sentence max)
    
    """
    

completion = openai.chat.completions.create(
model="gpt-4-0125-preview",
messages=[
{"role": "system", "content": system_prompt},
{"role": "user", "content": user_prompt3}
],
temperature=0.7,
max_tokens=2000,
top_p=0.95,
frequency_penalty=0,
presence_penalty=0,
stop=None
)

    
print(completion.choices[0].message.content) # This prints the content of the output in a more readable way
print("\n---\n")  # This adds a separator between the messages for readability
# Out:
# 1) **Universal Automation Language (UAL)**
#    - A standardized programming language for all automation equipment.
#    - Engineers code once in UAL, which then automatically translates into specific languages for each piece of equipment.
#    - Breaks the barrier of proprietary languages, enabling seamless integration.
#    - Inspired by the need for cloud-based management and API-based architectures in factory automation (Software Defined Automation).
#
# 2) **Factory Metaverse Interface (FMI)**
#    - A virtual reality platform for factory automation design and testing.
#    - Operators use VR headsets to interact with and test automation setups before physical implementation.
#    - Introduces a risk-free, immersive environment for testing and optimization.
#    - Draws inspiration from the concept of the Industrial Metaverse and its integration into operational processes (Worlds Enterprises).
#
# 3) **Predictive Integration AI (PIA)**
#    - An AI system that predicts and automates integration tasks.
#    - The system learns from existing factory setups and automatically suggests optimizations and integrations for new equipment.
#    - A self-optimizing factory environment constantly improving efficiency.
#    - Novel because it uses predictive analytics for real-time system integration, an approach not yet applied in factory automation.
#
# 4) **Blockchain-Enabled Supply Chain (BESC)**
#    - Decentralized automation equipment registration and communication system.
#    - Each piece of equipment logs data to a secure blockchain, accessible by all connected systems, ensuring instant interoperability.
#    - A transparent, secure way to ensure equipment compatibility and traceability.
#    - Novelty lies in applying blockchain technology for real-time, secure, and decentralized communication between automation systems.
#
# 5) **Cognitive Robotic Retrofitting (CRR)**
#    - Smart adapters that retrofit existing equipment for interoperability.
#    - Operators attach the adapters to non-compatible machinery, enabling them to communicate and operate with newer systems seamlessly.
#    - Allows for the gradual integration of cutting-edge technologies without full system overhauls.
#    - Unique because it combines cognitive computing with physical retrofitting, a new approach to upgrading factory automation systems.
#
# Inspiration drawn from the articles included the advancements in AI and robotics (Aniai), the application of digital twins in the Industrial Metaverse (Worlds Enterprises), and the innovative use of cloud technologies for automation (Software Defined Automation).
#
# ---
#
# **1) Universal Automation Language (UAL)**
#
# - **Summary**: UAL is a standardized programming language for automation equipment, translating code into specific languages for each device, facilitating seamless integration. Inspired by software-defined automation, it aims to eliminate proprietary language barriers.
# - **Evaluation criteria 1 detail**: To realize UAL, extensive collaboration among equipment manufacturers is needed to agree on standards. This would require developing a comprehensive syntax and semantics framework that all parties can adopt. Additionally, it involves creating a robust translation engine capable of converting UAL code to various proprietary languages. Significant investment in research and development, as well as industry-wide cooperation, would be essential.
# - **Evaluation criteria 1**: 2
#
# **2) Factory Metaverse Interface (FMI)**
#
# - **Summary**: FMI uses VR to allow operators to design and test factory automation in a virtual environment, reducing implementation risks and fostering optimization. It leverages the concept of the Industrial Metaverse for operational process integration.
# - **Evaluation criteria 1 detail**: Implementing FMI requires advanced VR technology, robust software for simulation and design, and high-speed computing resources. Knowledge in VR application development, simulation modeling, and factory automation processes is essential. Additionally, creating an immersive and interactive virtual environment that accurately mimics real-world physics and machinery behavior is crucial.
# - **Evaluation criteria 1**: 3
#
# **3) Predictive Integration AI (PIA)**
#
# - **Summary**: PIA is an AI system that learns from existing setups to predict and automate integration tasks, suggesting optimizations for new equipment, thus enhancing factory efficiency continuously. It employs predictive analytics for system integration.
# - **Evaluation criteria 1 detail**: For PIA, developing sophisticated machine learning algorithms capable of understanding complex factory environments is necessary. It would also involve collecting and analyzing vast datasets from various factory setups to train the AI accurately. Ensuring data privacy and security, along with integrating the system across diverse automation platforms, are key challenges.
# - **Evaluation criteria 1**: 2
#
# **4) Blockchain-Enabled Supply Chain (BESC)**
#
# - **Summary**: BESC uses blockchain for decentralized automation equipment registration and communication, ensuring interoperability, security, and traceability by logging data accessible to all systems. It applies blockchain technology for real-time system communication.
# - **Evaluation criteria 1 detail**: BESC's realization requires the adoption of blockchain technology across the supply chain, necessitating consensus on data standards and protocols. Technical knowledge in blockchain development, smart contracts, and secure data encryption methods is crucial. Moreover, it involves overcoming scalability issues and ensuring the system's compatibility with existing factory automation systems.
# - **Evaluation criteria 1**: 2
#
# **5) Cognitive Robotic Retrofitting (CRR)**
#
# - **Summary**: CRR employs smart adapters to retrofit existing machinery for compatibility with new systems, enabling seamless communication without full system overhauls. It combines cognitive computing with physical retrofitting for system upgrades.
# - **Evaluation criteria 1 detail**: Realizing CRR involves developing adaptable, intelligent adapters that can interface with a wide range of machinery and translate communication protocols. This requires advancements in cognitive computing, robotics, and interoperability standards. Engineering challenges include creating physically adaptable modules and ensuring their reliability and safety in diverse factory environments.
# - **Evaluation criteria 1**: 2
#
# ---
#
# **1) Universal Automation Language (UAL)**
#
# - **Title**: Universal Automation Language (UAL)
# - **Summary**: UAL proposes a unified programming language for factory automation equipment, aiming to bridge the communication gap between different devices by translating code. This would require a significant shift towards standardization among manufacturers and the development of a versatile translation engine.
# - **Evaluation criteria 2 details**: The challenge of achieving consensus among diverse manufacturers and the complexity of developing a universally adaptable translation engine may limit UAL's practical implementation.
# - **Evaluation criteria 2**: 1
#
# **2) Factory Metaverse Interface (FMI)**
#
# - **Title**: Factory Metaverse Interface (FMI)
# - **Summary**: FMI leverages virtual reality to enable operators to design, test, and optimize factory automation systems in a virtual setting, potentially reducing real-world implementation risks. It relies on advanced VR and computing technology to simulate physical factory environments accurately.
# - **Evaluation criteria 2 details**: The feasibility of accurately simulating complex factory dynamics and the high costs associated with VR technology development and deployment may hinder FMI's adoption.
# - **Evaluation criteria 2**: 2
#
# **3) Predictive Integration AI (PIA)**
#
# - **Title**: Predictive Integration AI (PIA)
# - **Summary**: PIA introduces an AI system designed to learn from existing factory setups to predict integration challenges and propose optimizations, continually enhancing efficiency. It depends on sophisticated machine learning algorithms and extensive data collection.
# - **Evaluation criteria 2 details**: The requirement for vast, diverse data sets and the challenge of developing AI that can accurately model complex, real-world factory environments present significant hurdles.
# - **Evaluation criteria 2**: 2
#
# **4) Blockchain-Enabled Supply Chain (BESC)**
#
# - **Title**: Blockchain-Enabled Supply Chain (BESC)
# - **Summary**: BESC utilizes blockchain technology to facilitate decentralized communication and data logging among automation equipment, aiming to improve interoperability and traceability. It requires widespread adoption of blockchain standards across the supply chain.
# - **Evaluation criteria 2 details**: The scalability of blockchain technology and the need for industry-wide standardization of data protocols could significantly limit BESC's applicability and effectiveness.
# - **Evaluation criteria 2**: 1
#
# **5) Cognitive Robotic Retrofitting (CRR)**
#
# - **Title**: Cognitive Robotic Retrofitting (CRR)
# - **Summary**: CRR employs intelligent adapters to retrofit existing machinery, enabling compatibility with newer systems and facilitating seamless communication. This approach combines advancements in cognitive computing and robotics to address system upgrade challenges.
# - **Evaluation criteria 2 details**: The engineering complexity of creating universally adaptable, reliable adapters and ensuring their safety across various factory settings poses a substantial challenge.
# - **Evaluation criteria 2**: 2
#
# ---
# **Name**: Universal Automation Language (UAL)
#
# **Solved Problem**: Fragmentation due to proprietary programming languages in factory automation systems.
#
# **Solution**: UAL proposes a standardized programming language for automation equipment, enabling engineers to code once and automatically translate it into specific languages for each device. This innovation aims to facilitate seamless integration and communication between different systems. By breaking down the barriers of proprietary languages, UAL ensures compatibility across diverse automation technologies.
#
# **Impact**: The implementation of UAL would streamline the development and integration process for factory automation systems, reducing the time and effort required for engineers to program each piece of equipment individually. It would also significantly decrease system downtime caused by integration issues, leading to more efficient workflows and improved overall performance. Moreover, it could foster greater innovation by allowing easier incorporation of new technologies into existing systems.
#
# **Technology**: UAL would utilize a robust translation engine capable of interpreting UAL code and converting it into the proprietary languages of various automation equipment. This requires the development of a comprehensive syntax and semantics framework that all participating manufacturers agree upon. The engine would leverage advanced algorithms to ensure accurate, efficient translation across different systems, relying heavily on cloud-based management for scalability and API-based architectures for flexibility. This approach is inspired by software-defined automation principles, aiming to create a more adaptable and interoperable factory automation landscape.
#
# **Sources**: Inspired by the need for software-defined automation.
#
# ---
#
# **Name**: Factory Metaverse Interface (FMI)
#
# **Solved Problem**: Risk and inefficiency in designing and testing automation systems.
#
# **Solution**: FMI utilizes virtual reality to allow engineers and operators to design, simulate, and test factory automation setups in a virtual environment before physical implementation. This virtual platform offers an immersive, interactive experience, enabling risk-free experimentation and optimization. It drastically reduces the time and resources spent on trial and error in real-world setups.
#
# **Impact**: By simulating real factory environments, FMI allows for thorough testing and optimization of automation strategies without the high costs and potential downtime associated with physical prototyping. It enables early identification and correction of design flaws, enhancing the overall efficiency and reliability of factory automation systems. Additionally, FMI can accelerate the adoption of new technologies by providing a safe space for experimentation and learning.
#
# **Technology**: FMI leverages advanced VR technology alongside robust simulation and design software capable of accurately mimicking the physics and behavior of real-world factory machinery and processes. It requires high-speed computing resources to render detailed, interactive virtual environments in real-time. The technology draws upon the concept of the Industrial Metaverse, integrating operational processes with digital twins to create a seamless bridge between virtual planning and physical execution.
#
# **Sources**: Draws inspiration from the Industrial Metaverse.
#
# ---
#
# **Name**: Predictive Integration AI (PIA)
#
# **Solved Problem**: Manual integration tasks and suboptimal equipment performance.
#
# **Solution**: PIA introduces an AI system that learns from existing factory setups to automatically predict and execute integration tasks for new equipment, suggesting optimizations to enhance efficiency. It uses machine learning to analyze data from various setups, continuously improving its recommendations. This creates a self-optimizing factory environment that minimizes manual intervention.
#
# **Impact**: PIA significantly reduces the time and expertise required to integrate new machinery into existing systems, minimizing downtime and improving productivity. By predicting optimal integration strategies and adjustments, it ensures that factory operations are always running at peak efficiency. Additionally, it fosters innovation by making it easier to incorporate and optimize new technologies.
#
# **Technology**: The core of PIA involves sophisticated machine learning algorithms that can process and analyze large datasets from different factory environments to understand complex integration challenges. It requires a secure and scalable data collection and analysis framework to train the AI effectively. The system also needs to ensure data privacy and integrate seamlessly across diverse automation platforms, employing predictive analytics to anticipate and solve integration issues in real time.
#
# **Sources**: Novel because of its use of predictive analytics for system integration.
#
# ---
#
# **Name**: Blockchain-Enabled Supply Chain (BESC)
#
# **Solved Problem**: Lack of interoperability and traceability in factory automation equipment.
#
# **Solution**: BESC utilizes blockchain technology to create a decentralized system for automation equipment registration and communication, ensuring all devices can securely log data and interact with each other. This promotes instant interoperability and provides a transparent, traceable record of all interactions and transactions. It addresses compatibility and security challenges head-on, facilitating smoother integration of disparate systems.
#
# **Impact**: The implementation of BESC would ensure real-time, secure communication between automation systems, significantly reducing integration times and compatibility issues. It would also enhance transparency and traceability throughout the supply chain, improving accountability and efficiency. Furthermore, it could pave the way for more dynamic and responsive automation ecosystems, adaptable to changes and new technologies.
#
# **Technology**: BESC requires the development of consensus mechanisms and data standards that allow automation equipment to communicate and register information on a blockchain. This involves technical expertise in blockchain development, including smart contracts and secure data encryption methods. The system must overcome scalability challenges inherent to blockchain technology while ensuring compatibility with existing factory automation protocols. It represents a novel application of blockchain for real-time, decentralized communication within the automation industry.
#
# **Sources**: Novelty lies in applying blockchain technology for communication between automation systems.
#
# ---
#
# **Name**: Cognitive Robotic Retrofitting (CRR)
#
# **Solved Problem**: Incompatibility between new and existing factory automation equipment.
#
# **Solution**: CRR offers smart adapters that can be attached to existing machinery, enabling them to communicate and operate seamlessly with newer systems. These adapters leverage cognitive computing to interpret and translate between different communication protocols, bridging the gap between old and new technologies. It allows for a gradual, cost-effective upgrade of factory systems without the need for complete overhauls.
#
# **Impact**: CRR facilitates the integration of cutting-edge technologies into legacy systems, extending the life and enhancing the capabilities of existing equipment. It reduces the financial and operational barriers to adopting new automation technologies, making it easier for factories to stay competitive. Additionally, it minimizes downtime and disruption associated with system upgrades, maintaining productivity during transitions.
#
# **Technology**: The technology behind CRR involves the development of intelligent, adaptable modules that utilize cognitive computing to understand and translate various communication protocols. These modules must be engineered to physically fit and function with a wide range of machinery, requiring advancements in robotics and interoperability standards. Ensuring the reliability and safety of these adapters in diverse factory environments is a critical engineering challenge, representing a unique blend of cognitive computing and physical retrofitting techniques.
#
# **Sources**: Unique because it combines cognitive computing with physical retrofitting.
#
# ---
