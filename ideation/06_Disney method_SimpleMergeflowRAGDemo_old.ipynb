# %%
# !pip install python-dotenv
# !pip install openai
# Out:
# Requirement already satisfied: python-dotenv in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (1.0.0)
# Requirement already satisfied: openai in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (1.8.0)
# Requirement already satisfied: sniffio in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from openai) (1.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from openai) (1.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from openai) (3.5.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from openai) (4.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from openai) (2.5.3)
# Requirement already satisfied: tqdm>4 in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from openai) (4.64.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from openai) (0.26.0)
# Requirement already satisfied: idna>=2.8 in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai) (3.3)
# Requirement already satisfied: certifi in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai) (2022.9.24)
# Requirement already satisfied: httpcore==1.* in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /Users/leonarddavid/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (2.14.6)

# %% [markdown]
# # Getting data from Mergeflow's API

# %%
import requests
import json
import os
from dotenv import load_dotenv # stores API keys for OpenAI and Mergeflow 

load_dotenv()  # Load variables from .env file
mergeflow_api_key = os.getenv('MERGEFLOW_API_KEY') # Assign Mergeflow API

# the API call
query = 'AI+Water+Concierge|AWC|AI+for+water+management|AI+in+water+conservation|AI+in+water+usage|AI+for+water+efficiency|AI+in+water+systems
dataset = '&sp=2655' # access dataset from mergeflow - in this case venture capital investments
rows = str(3) # first 20 docs only

# in the url below, replace "fw" by your user name. You can see your user name at mergeflow.net
# -> Account -> the string in angle brackets
url = 'https://mergeflow.net/api/v1/ferdinandk/search/getContent?q=' + query + dataset + '&rows=' + rows


# Define the headers to be sent with the request
headers = {
    'MergeflowNet-Api-Auth-Key': mergeflow_api_key
}

# Get and print the response
response = requests.post(url, headers=headers)

mergeflow_docs = []

# Check the response status code and content
if response.status_code == 200:
    mergeflow_response_json = response.json()
    
    # Pretty-print the JSON response -- useful to understand what the JSON looks like
    #pretty_json = json.dumps(mergeflow_response_json, indent=4)
    #print(pretty_json)
    
    # get title, URL, date, and content
    for document in mergeflow_response_json['Documents']:
        current_doc = {
            'title': document['Title'],
            'date': document['Date'],
            'url': document['Url'],
            'content': document['Content']
        }
        
        mergeflow_docs.append(current_doc)
        #print(content)        

    print('Found ' + str(len(mergeflow_docs)) + ' documents.')

else:
    print('Request failed with status code:', response.status_code)
    print(response.text)  # Print the response text
# Out:
#   File "/var/folders/nt/p2r023612c74fk40qrw64s6m0000gn/T/ipykernel_3434/2289041961.py", line 10
#     query = 'AI+Water+Concierge|AWC|AI+for+water+management|AI+in+water+conservation|AI+in+water+usage|AI+for+water+efficiency|AI+in+water+systems
#                                                                                                                                                   ^
# SyntaxError: EOL while scanning string literal

# %%
import openai
import os
import requests
import json

openai.api_key = os.getenv('OPENAI_API_KEY')

summary_list = []

system_prompt_summary = f"""
You are a highly qualified academic scholar who has much experience in communicating your results to a broad audience. You are able to extract the most important aspects of texts, compress them and rephrase them in a comprehensible way.
"""

for doc in mergeflow_docs:
    user_prompt_summary = f"""
    Consider the text below, delimited by ```, in the area of {query}:
    ```
    {doc['content']}
    ```
    Please summarize the finding of the text in at most 500 words, and clearly cite the source at the end.
    """
    completion_summary = openai.chat.completions.create(
        model="gpt-3.5-turbo-0125",
        messages=[
            {"role": "system", "content": system_prompt_summary},
            {"role": "user", "content": user_prompt_summary}
        ],
        temperature=0.7,
        max_tokens=2000,
        top_p=0.95,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None
    )

    summary_list.append(completion_summary.choices[0].message.content)
    print(completion_summary.choices[0].message.content)
    print("\n---\n")


print(summary_list)
print("\n----------------------------------------------\n----------------------------------------------\n")
# Out:
# The text discusses Aniai, a New York City-based robotic company and kitchen solutions provider, securing $12 million in Pre-Series A funding. The funding round was led by InterVest, with participation from SV Investment, Ignite Innovation, and Capstone Partners. Aniai plans to use the funds to establish its first manufacturing facility, Factory One, in South Korea. This move aims to ensure stable production and efficient supply chain management for its flagship product, the Alpha Grill. The company, founded in 2020 by CEO Gunpil Hwang, specializes in developing robotic solutions for cooking hamburgers. The Alpha Grill utilizes robotics to cook hamburgers, featuring a double-sided grill capable of cooking up to eight patties simultaneously or 200 patties per hour. This technology helps restaurant brands streamline operations by automating tasks like pressing and flipping patties, reducing cooking time, and easing the labor burden on employees.
#
# Gunpil Hwang expressed that the funding will support Aniai's mission to enhance kitchen productivity through robotics and automation. The company plans to scale up production to meet current and future demand. Additionally, Aniai intends to enhance the capabilities of the Alpha Grill by integrating advanced, cloud-based AI software. This upgrade is expected to further improve the performance of the grill, benefiting both existing and new customers.
#
# In conclusion, Aniai's successful funding round will enable the company to establish a manufacturing facility in South Korea, enhance production capabilities, and integrate advanced AI software into its flagship product, the Alpha Grill. This strategic move aligns with the company's goal of revolutionizing kitchen productivity through innovative robotic solutions.
#
# Source: Aniai Closes $12M Pre-Series A Funding
#
# ---
#
# Virdee, a company based in Austin, Texas, specializing in guest experience technology and check-in automation, recently secured $12.4 million in Series A funding. The funding round was led by Moneta Ventures, with participation from Silverton Partners, Koch Real Estate Investments, Alumni Ventures, DJR Advisors, Capital Factory, and other partners. Brent Kelton, a Partner at Moneta Ventures, also joined Virdee's board as part of the funding agreement.
#
# This investment brought Virdee's total funding amount to $21 million, following previous financial support from Silverton Partners in a Seed financing round in February 2022 and angel investment in 2020 led by Rajiv Trivedi, former President of La Quinta Inns & Suites. Founded in 2020 by Branigan Mulcahy and Nadav Cornberg, Virdee offers a software platform for the hospitality industry that enhances guest experiences and automates check-in processes through various digital channels such as web, app, kiosk, and SDK options.
#
# Virdee's platform leverages digital applications and AI to streamline front desk transactions, enabling hotels of all sizes to integrate their solution seamlessly and improve guest interactions. By offering contactless hotel check-in capabilities that are compatible with diverse systems, including web, app, and kiosk-based setups, Virdee's technology supports features like Virdee Identity, upgrades, upsells, and Remote Assistance, facilitating 100% of guest check-ins. The company's client base includes prominent casino hotels in Las Vegas and other major hotel brands, highlighting the effectiveness and versatility of Virdee's solutions in the hospitality sector.
#
# In summary, Virdee's recent funding milestone underscores the growing recognition and adoption of its innovative guest experience technology and check-in automation platform within the hospitality industry. The company's strategic partnerships and expanding installation base further solidify its position as a leading provider of solutions that enhance guest satisfaction, streamline operations, and elevate overall hotel experiences.
#
# Source: "Virdee Closes $12.4M in Series A Funding" - Original text provided.
#
# ---
#
# Cellares, an integrated development and manufacturing organization (IDMO) based in South San Francisco, recently secured $255 million in Series C funding. The funding round was led by Koch Disruptive Technologies, along with participation from Bristol Myers Squibb, DFJ Growth, Willett Advisors, and existing investors such as Eclipse, Decheng Capital, and 8VC. As part of the financing, David Mauney from Koch Disruptive Technologies will be joining Cellares' board of directors.
#
# Under the leadership of CEO Fabian Gerlinghaus, Cellares focuses on developing and operating integrated technologies for cell therapy manufacturing to expedite the availability of life-saving cell therapies. One of its key innovations is the Cell Shuttle, a flexible platform that streamlines the entire manufacturing process by integrating all necessary technologies, enabling walk-away, end-to-end automation.
#
# Currently, Cellares operates two Smart Factories in the United States and is in the process of planning a third. The first Smart Factory in South San Francisco is currently utilized for preclinical process development and transitioning manual processes onto the Cell Shuttle for existing partners. By the first half of 2024, this facility is expected to be cGMP-ready.
#
# Additionally, Cellares is establishing a 118,000 sq. ft. IDMO Smart Factory in Bridgewater, New Jersey, which will have the capacity to produce 40,000 cell therapy batches annually. This site is slated to be cGMP-ready by the second half of 2024. While the company can support clinical trials in Europe from its US Smart Factories, it also has plans to construct its first IDMO Smart Factory in Europe in 2024.
#
# In summary, Cellares' recent Series C funding of $255 million, led by Koch Disruptive Technologies, marks a significant milestone for the company as it continues to advance its mission of revolutionizing cell therapy manufacturing through innovative technologies and operational excellence.
#
# Source: Original text from "Cellares Raises $255M in Series C Funding" in the field of factory automation.
#
# ---
#
# Terabase Energy, a leader in digital and automation solutions for solar power plants, recently secured $25 million in funding to accelerate the commercial scale-up of its Terafab construction automation system. The funding round was led by Fifth Wall, a prominent asset manager focused on improving and decarbonizing the built world, with participation from EDP Ventures and existing investors. This investment aims to support Terabase's innovative approach to automating the construction of solar power plants, particularly through the Terafab system, which is described as the world's first automated, digital field factory for such construction.
#
# Anastasia Istratova from Fifth Wall expressed enthusiasm for supporting Terabase's vision of revolutionizing the solar industry, emphasizing the groundbreaking nature of the company's approach. Luis Manuel from EDP Ventures highlighted Terabase's role in addressing the renewable energy sector's need for rapid scaling to meet ambitious growth targets. The funding is expected to expedite the scaling of Terafab production, ensuring that Terabase can effectively meet rising demand as they deploy the system.
#
# In addition to its construction automation system, Terabase Energy's momentum extends to its software products. The company's construction management software, Construct, has been rapidly adopted by leading developers and EPCs for over 5 gigawatts of projects. Furthermore, Terabase's solar energy modeling tool, PlantPredict, has surpassed 2.8 terawatts of simulations across more than 30,000 projects, indicating a growing demand for accurate solar plant performance modeling.
#
# Terabase Energy's overarching mission is to reduce costs and expedite the deployment of utility-scale solar through construction automation and software solutions. Their platform enables the rapid deployment of solar plants at competitive costs, supporting grid-connected PV plants and the future production of green hydrogen with PV. Their product suite includes PlantPredict for solar plant design and energy modeling, Construct for digital construction management, Terafab for construction automation, and power plant control and SCADA solutions.
#
# Founded in 2016, Fifth Wall is a key player in the investment landscape, focusing on improving and decarbonizing the built world. With significant capital raised and a diverse range of strategic partners, Fifth Wall collaborates with portfolio companies to drive emissions reductions, efficiency improvements, and maximize returns in the built world ecosystem.
#
# EDP Ventures, the corporate venture capital arm of EDP, a global energy company, supports and invests in Energy and Climate Tech startups to drive innovation in the energy industry. By providing financial investment, mentoring, and access to resources, EDP Ventures aims to accelerate the growth of promising startups in the energy sector.
#
# In conclusion, Terabase Energy's recent funding round and strategic partnerships with Fifth Wall and EDP Ventures underscore the company's commitment to revolutionizing the solar industry through digital and automation solutions, ultimately contributing to the transformation of the renewable energy sector.
#
# Source: Business Wire
#
# ---
# Numbers Station, a company based in Menlo Park, CA, has recently secured $17.5 million in funding through a series A round and seed funding. The funding was led by Madrona, a prominent venture capital firm. This round included a $12.5 million series A funding led by Madrona, with participation from Norwest Venture Partners, Factory, and notable angel investors like Jeff Hammerbacher, who is a co-founder of Cloudera. Prior to this, Numbers Station had also raised $5 million in a seed funding round, bringing their total capital raised to $17.5 million.
#
# Numbers Station specializes in an intelligent data stack automation platform that leverages foundation model technology developed at the Stanford AI lab. The platform is designed to streamline data work processes by automating tedious tasks, particularly in the area of data transformation. This automation enables data workers to quickly generate valuable insights, enhancing efficiency and productivity in data-related tasks.
#
# In conclusion, Numbers Station's recent funding of $17.5 million, with contributions from key investors like Madrona and notable individuals in the industry, signifies a significant milestone for the company. Their focus on utilizing advanced technology to automate data work processes demonstrates a commitment to innovation and efficiency in the field of factory automation.
#
# Source: Original text excerpt from undisclosed publication.
#
# ---
#
# Numbers Station, a Menlo Park, CA-based company, has secured $17.5 million in funding for its intelligent data stack automation platform. The funding includes a $12.5 million Series A round led by Madrona, with participation from Norwest Venture Partners, Factory, and notable angel investors like Jeff Hammerbacher. This investment follows a previous $5 million seed round, bringing the total capital raised to $17.5 million. As part of this funding round, Tim Porter from Madrona has joined the Numbers Station board.
#
# Established in 2021 by CEO Chris Aberger, Numbers Station offers a platform that leverages proprietary foundation model technology to enable data practitioners of all levels to automate workflows within the modern data stack using natural language. The platform caters to a wide range of data tasks, from basic formatting to complex tasks like entity resolution and extraction. By integrating artificial intelligence (AI), Numbers Station empowers data workers to connect to their data warehouse, prototype intelligent data transformations through a conversational interface, and deploy pipelines back into their data warehouse. This allows customers to apply automated pipelines to various business use cases across departments that require heavy analytics.
#
# Numbers Station, currently available in private beta, is built on research conducted at the Stanford AI Lab by Chief Scientist and Co-founder Ines Chami, along with founding team members Chris Aberger, Sen Wu, and Chris Re. The platform is designed to work with any foundation model in tandem with proprietary foundation models and algorithms tailored for managing data-intensive tasks.
#
# In summary, Numbers Station's recent funding of $17.5 million, with a significant contribution from Madrona, underscores the growing interest in intelligent data stack automation platforms that simplify and accelerate data workflows for users of all skill levels. The platform's integration of natural language processing and AI technologies positions it as a valuable tool for organizations seeking to streamline data processes and enhance analytics capabilities.
#
# Source: Numbers Station Raises $17.5M in Funding. Retrieved from [insert source link here].
#
# ---
#
# Numbers Station, an intelligent data stack automation platform, has raised $17.5 million in funding to further develop its AI-powered technology. The funding round was led by Madrona, with participation from Norwest Venture Partners, Factory, and notable angel investors like Jeff Hammerbacher. This investment follows a previous $5 million seed round, bringing the total capital raised to $17.5 million.
#
# Utilizing foundation model technology pioneered at the Stanford AI lab, Numbers Station aims to democratize access to AI by enabling data workers to automate tedious data transformation tasks. The platform allows all data practitioners to generate insights rapidly without the need for coding or AI expertise, starting with data transformation work. By leveraging foundation models in language, image, and code generation, Numbers Station empowers data analytics teams to streamline their data workflows and gain valuable insights from complex and siloed data.
#
# Numbers Station's platform enables users to connect to their data warehouse, prototype intelligent data transformations through a conversational interface, and deploy automated pipelines back into their data warehouse. This approach allows organizations to apply automated data workflows to various business use cases across departments, from marketing and customer success to product and finance analytics.
#
# The technology developed by Numbers Station not only accelerates the process of data preparation and transformation but also facilitates communication and collaboration between different data teams within an organization. By automating data-intensive workflows, Numbers Station frees data engineers from backlogs of requests and reduces costly communication gaps, enabling enterprises to obtain insights quickly and share them with decision-makers in a matter of hours rather than months.
#
# The platform's proprietary foundation model technology, combined with intelligent transforms and automated workflows, addresses the challenges that have long plagued the data industry. Numbers Station's innovative approach resonates with industry experts who have struggled with extracting insights from messy data for years, signaling a fundamental shift in how work is conducted on the modern data stack.
#
# In summary, Numbers Station's intelligent data stack automation platform, built on proprietary foundation model technology, empowers data practitioners of all skill levels to automate workflows using natural language interactions. The platform's ability to simplify the setup of data pipelines, clean and enrich data, and perform various data-related tasks is positioned to revolutionize how organizations handle their data processes.
#
# Source: Numbers Station Raises $17.5 million for AI-powered Data Stack Automation | Business Wire
#
# ---
#
# Worlds Enterprises, a Dallas-based company, recently secured $21 million in Series A1 funding. The funding round was led by Moneta Ventures and included participation from Align Capital, Green Park & Golf Ventures, Chevron Technology Ventures, Piva Capital, PerotJain, and Capital Factory. The company, led by CEO Dave Copps and President Chris Rohde, specializes in providing a 4D infrastructure for the Industrial Metaverse.
#
# Worlds' innovative platform integrates AI-based automation into the daily operations of large industrial companies, allowing for real-time data streaming and analysis. This approach enables organizations to optimize their processes, identify inefficiencies, and unlock significant untapped value. The company primarily targets sectors within the supply chain, such as manufacturing, distribution, logistics, transportation, energy, and national defense.
#
# Despite being a relatively new player in the market, Worlds has already gained traction among major industrial firms like Chevron, PETRONAS, and Hillwood Development Company. Their market launch in August 2021 has been well-received, with these companies leveraging Worlds' platform to enhance their operational efficiency and decision-making processes.
#
# In summary, Worlds Enterprises' successful Series A1 funding round reflects investor confidence in the company's innovative approach to integrating AI automation into industrial processes. The company's focus on the Industrial Metaverse and its ability to deliver tangible benefits to large industrial players have positioned it as a key player in the industry.
#
# Source: Worlds Raises $21M in Series A1 Funding, Retrieved from [Insert Source Here]
#
# ---
#
# Worlds Enterprises, Inc. has secured $21.2 million in Series A1 funding to expand its Industrial Metaverse platform. The funding round was led by Moneta Ventures, with contributions from Align Capital, Green Park & Golf Ventures, Chevron Technology Ventures, Piva Capital, PerotJain, and Capital Factory. This financial boost will be utilized to enhance the company's AI platform, strengthen key partnerships, and drive the adoption of Worlds' technology by industrial entities.
#
# The Industrial Metaverse platform developed by Worlds integrates AI-driven automation into the operational core of large industrial firms. By amalgamating IoT sensors, personnel, and processes within a dynamic digital twin, organizations can evaluate and transform their operations in innovative ways that were previously unattainable. CEO Dave Copps expressed excitement over the shared vision of digital transformation among investors, emphasizing the pivotal role Worlds plays in converging digital and physical realms to revolutionize business operations.
#
# In a competitive market saturated with specialized solutions, Worlds stands out by offering a comprehensive platform that unifies various components crucial for digital transformation. President Chris Rohde highlighted the necessity for a centralized solution that integrates disparate technologies, a gap that Worlds aims to bridge effectively. The company has already garnered trust from major industrial players like Chevron, PETRONAS, and Hillwood Development Company, with substantial growth in Annual Recurring Revenue (ARR) and ongoing expansions with clients projected for 2023.
#
# Investors such as Moneta Ventures and Align Capital lauded Worlds' innovative 4D infrastructure for the Industrial Metaverse, underscoring its disruptive impact on industrial operations. Aasim Hasan from Moneta Ventures praised the platform for its uniqueness and market redefinition, predicting significant growth potential. Lisa Harris of Align Capital commended Worlds' leadership and technology, emphasizing the transformative influence on Fortune 100 clients and the continued investment in the company.
#
# Worlds' focus on sectors within the supply chain, including manufacturing, distribution, logistics, transportation, energy, and national defense, underscores its broad applicability and potential for widespread industry impact. By converting everyday processes into a real-time data stream, Worlds empowers organizations to extract untapped value through enhanced measurement and analysis capabilities.
#
# In conclusion, Worlds Enterprises, Inc. has secured substantial funding to advance its groundbreaking Industrial Metaverse platform, positioning itself as a key player in driving digital transformation within the industrial sector.
#
# Source: Business Wire
#
# ---
# The text discusses Software Defined Automation, a company that recently secured $10 million in seed funding. Insight Partners led the funding round, with participation from Baukunst VC, Fly Ventures, and First Momentum. Jon Rosenbaum from Insight Partners and Axel Bichara from Baukunst will join the company's Board of Directors as part of the transaction.
#
# Software Defined Automation specializes in innovating factory automation through its Industrial-Control-as-a-Service (ICaaS) offering. This service revolves around cloud-based management of existing PLCs (TechOps), Git-enabled PLC code versioning and collaboration (DevOps), and virtualization of PLCs on edge servers (Virtual PLC). By integrating these technologies, the company aims to dismantle proprietary silos in control technology stacks and facilitate an API-based modern microservices architecture.
#
# The company operates from offices in both Boston, US, and Munich, Germany.
#
# In conclusion, Software Defined Automation's successful fundraising efforts highlight the growing interest and investment in advancements in factory automation, particularly in the realm of Industrial-Control-as-a-Service. The company's focus on breaking down traditional barriers in control technology and embracing modern approaches like cloud-based management and virtualization signifies a shift towards more agile and interconnected automation systems.
#
# Source: Software Defined Automation Raises $10M in Seed Funding
#
# ---
#
# The text discusses Viaphoton, a fiber connectivity provider that recently raised $80 million to enhance fiber production at the edge. The company has developed an innovative manufacturing process that incorporates mass customization, data center engineering automation, and robotic process automation (RPA) to streamline fiber optics equipment manufacturing. Viaphoton was founded in 2020 by Baber Abbas (CEO) and Wasif Khan (CFO) to address the increasing demand for customized fiber connectivity at the edge. They have combined mass customization techniques with new design tools to cater to the unique needs of infrastructure builders, significantly reducing the production time from months to weeks.
#
# The demand for global fiber connectivity in data centers, 5G networks, and broadband is rapidly increasing, surpassing the capabilities of copper-based networks. Viaphoton's approach enables infrastructure providers to accurately specify their unique requirements, leading to quicker and more flexible production processes. Traditional methods of manually cutting and splicing fiber in the field are time-consuming and error-prone, making factory production a more efficient solution.
#
# Viaphoton's success is evident from its financial growth, with total investments amounting to $100 million, annual revenue exceeding $40 million by Q4 of 2021, and a significant increase in staff members. The company plans to utilize the recent investment to enhance its technology platform, operational capacity, sales capacity, and expand into the European market. Competitors in the fiber optic market include established companies like Corning, Prysmian, Finisar, and Sumitomo.
#
# Overall, Viaphoton's disruptive approach to fiber manufacturing, focusing on customization and speed, aligns with the growing market trends and the increasing need for efficient fiber connectivity solutions. The company's rapid growth and strategic investment plans indicate a promising future in the evolving fiber optic industry.
#
# Source: "Viaphoton raises $80M to disrupt fiber manufacturing" by VentureBeat
#
# ---
#
# The text discusses CloudNC's recent success in raising $45 million in a Series B funding round to further develop their AI manufacturing technology. The funding was led by Autodesk, with participation from Lockheed Martin and British Patient Capital, along with existing investors Atomico, Episode 1 Ventures, and QVentures. CloudNC aims to revolutionize precision manufacturing by providing a SaaS product that allows users to instruct CNC machines on how to create precision parts with a single click. This innovation is expected to enhance the ease, speed, and reliability of precision manufacturing processes, enabling customers to produce goods globally at a competitive cost.
#
# CloudNC's technology streamlines the precision manufacturing process by automating tasks traditionally reliant on expert manual programming. Users can upload a 3D model, and the software autonomously generates the necessary instructions for the CNC machine. This automation not only improves efficiency but also helps in upskilling the manufacturing workforce by enabling junior employees to operate the machines effectively.
#
# The ultimate goal of CloudNC's advanced software is to reduce reliance on manual programming, leading to faster, more reliable, and less wasteful manufacturing processes. By democratizing precision manufacturing, CloudNC aims to level manufacturing costs across regions, facilitate the establishment of local and resilient supply chains, and accelerate innovation in the industry.
#
# CloudNC's CEO and co-founder, Theo Saville, envisions a future where manufacturing becomes so simplified and democratized that nearly any product can be created with a single click, within days rather than months or years. This shift towards full manufacturing autonomy is projected to address a significant $200 billion problem in the industry and unlock new possibilities for businesses ranging from hobbyists to high-tech aerospace companies.
#
# The strategic partnerships with Autodesk and Lockheed Martin position CloudNC to expand its innovative solutions to factories worldwide. Autodesk, known for revolutionizing design and manufacturing processes, recognizes the potential of CloudNC's technology to drive productivity and innovation across industries. Lockheed Martin Ventures sees CloudNC's vision of end-to-end autonomous manufacturing as a valuable asset that can enhance capabilities within large-scale manufacturing operations.
#
# CloudNC's commitment to advancing precision machining is evident through its continuous development and testing of software in an aerospace-accredited facility. The company's unique full-stack factory in Essex, UK serves as a hub for refining and iterating towards achieving full manufacturing autonomy. Founded in 2015, CloudNC boasts a team with expertise in computer science and physical manufacturing, supported by strategic partnerships with industry leaders like Autodesk and Lockheed Martin.
#
# In summary, CloudNC's successful funding round and pioneering technology in autonomous manufacturing signify a significant step towards revolutionizing precision manufacturing processes globally. The company's vision of simplifying and democratizing manufacturing has the potential to reshape the industry landscape and accelerate innovation in production processes.
#
# Source: PRNewswire
#
# ---
#
# The text discusses Koidra, a Seattle-based company that recently secured $4.5 million in seed funding. Led by CEO Kenneth Tran, Koidra specializes in intelligent automation (IA) and is focused on industrial IoT applications for agriculture and industry. The company's innovative technology integrates physics, crop modeling, and machine learning to enhance Controlled Environment Agriculture (CEA) processes, thereby boosting yields and reducing waste in autonomous greenhouses. Koidra's IA platform empowers growers to monitor their growing environments, make optimized climate decisions, and improve yields continuously.
#
# Moreover, Koidra is expanding its IA technology to enhance operations in industrial IoT and real-time control scenarios, including machine and factory automation. The ultimate objective is to develop autonomous greenhouses, farms, and factories. The recent funding round was led by Ospraie Ag Science, with contributions from Amritam Holdings, Cavallo Ventures, and Foothill Ventures.
#
# In summary, Koidra's focus on intelligent automation and its application in agricultural and industrial settings, alongside its ambitious goal of creating autonomous facilities, positions the company as a key player in the realm of factory automation and industrial IoT.
#
# Source: Koidra Raises $4.5M in Seed Funding - FinSMEs
#
# ---
# Celona, an enterprise networking company based in Boca Raton, Florida, secured $60 million in Series C funding. This investment, led by DigitalBridge Group, Inc., with participation from existing investors like NTTVC, Lightspeed Venture Partners, and Qualcomm Ventures, brings the total capital raised by Celona to over $100 million. The company, under the leadership of Co-Founder and CEO Rajeev Shah, focuses on bridging LTE/5G cellular wireless technology with enterprise IT infrastructure to facilitate the adoption of business-critical applications in organizations. Celona's solution leverages the Citizens Broadband Radio Service (CBRS) spectrum to automate the deployment of cellular wireless networks by enterprise IT departments and managed service providers, streamlining their integration with existing IT systems.
#
# In November 2020, Celona introduced a fully-integrated 5G LAN platform designed to simplify the deployment, operation, and integration of 5G cellular networks within existing infrastructures. Recently, Celona partnered with Verizon Business to offer turn-key private networking solutions aimed at accelerating the adoption of enterprise 5G technology across various sectors, including factory automation, distance learning, real-time inventory management, and supply chain logistics.
#
# The collaboration with Verizon Business signifies Celona's commitment to providing comprehensive networking solutions that cater to diverse industry needs. By combining their expertise, Celona and Verizon Business aim to drive the adoption of 5G technology for various applications, such as factory automation, where reliable and high-speed connectivity is essential for optimizing operations and enhancing efficiency.
#
# Overall, Celona's successful funding round and strategic partnerships highlight the company's innovative approach to integrating cellular wireless technology with enterprise IT infrastructure. By focusing on automating network deployment and simplifying integration processes, Celona is well-positioned to support organizations in harnessing the benefits of 5G technology for improved business performance and operational efficiency.
#
# Source:
# - Original article: "Celona Raises $60M in Series C Funding" published on [Website Name], accessible at [URL]
#
# ---
#
# Linear Labs, a smart energy company based in Fort Worth, TX, recently secured $17 million in Series A funding. The funding round was led by THRC Investments and Folsom Point Equity, with participation from existing investors such as Lowercarbon Capital, Kindred Ventures, Saltwater Capital, Champion Hill Ventures, OzoneX Ventures, and Capital Factory. The company plans to utilize these funds to enhance its manufacturing capabilities, including expanding manufacturing expertise, improving supply chain infrastructure and logistics, advancing automation and robotics engineering, and adding engineering talent to its team.
#
# Under the leadership of Brad Hunstable, the founder and CEO, Linear Labs has introduced its new High Torque and Ultra High Efficiency electric motor along with an intelligence drive system known as the HET Light. This innovation is specifically designed to cater to the growing demand in the Light Electric Vehicle (LEV) industry. The company's production launch includes two models: the HET Light 30 and HET Light 45 Series. These patented systems outperform existing LEV motors with twice the torque and higher efficiency, contributing to increased vehicle performance, extended range, reduced vehicle weight, significant volume space savings, and the elimination of gear reduction.
#
# The LEV market is rapidly expanding and is projected to reach 125 million units globally by 2025. This market segment encompasses various smaller mobility vehicles such as neighborhood electric vehicles, small utility vehicles, golf carts, material handling vehicles, recreational vehicles, light electric motorcycles, e-bikes, and mopeds. Additionally, in 2021, the city of Fort Worth and Linear Labs finalized a substantial $68.9 million economic incentive package, aiming to establish the city as a prominent tech innovation hub.
#
# In conclusion, Linear Labs' successful Series A funding round and the introduction of its innovative electric motor and drive system mark significant developments in the company's journey towards meeting the evolving demands of the Light Electric Vehicle industry. This progress aligns with the broader trend of electrification in the transportation sector, particularly in the context of the growing LEV market.
#
# Source: Linear Labs Raises $17M in Series A Funding, Electric Vehicles
#
# ---
#
# RIOS Intelligent Machines, a company based in Menlo Park, California, specializing in AI-powered robotic workcells for factory automation, recently secured $28 million in Series A funding. This funding round, which included both equity funding and debt financing, was oversubscribed and led by Main Sequence, a new deep tech investor. Other major investors in this round included Yamaha Motor Ventures, Orbit Venture Partners, and Hypertherm Ventures. Existing investors such as Valley Capital Partners, Morpheus Ventures, and Grit Ventures also participated significantly, demonstrating confidence in RIOS' vision and growth prospects.
#
# With this Series A funding, RIOS Intelligent Machines' total capitalization now stands at $33 million, when combined with a $5 million venture round that was announced in 2020. This financial boost will enable RIOS to further develop its end-to-end AI-powered robotic workcells and expand its presence in the factory automation market. The successful funding round reflects investors' belief in the potential of RIOS Intelligent Machines to drive innovation and efficiency in the manufacturing industry.
#
# Source: RIOS Intelligent Machines Announcement, Retrieved from [URL or publication name]
#
# ---
#
# The text discusses Rios Intelligent Machines, a company based in Menlo Park, CA, that specializes in providing AI-powered robotic workcells for factory automation. Recently, the company secured $28 million in Series A funding through a combination of equity financing and debt. The funding round was led by Main Sequence, with participation from notable investors such as Yamaha Motor Ventures, Orbit Venture Partners, Hypertherm Ventures, Valley Capital Partners, Morpheus Ventures, and Grit Ventures.
#
# Rios, under the leadership of CEO Dr. Bernard Casse, focuses on helping businesses automate their factories, warehouses, and supply chain operations by deploying AI-powered robotic workcells that seamlessly integrate with existing workflows. These robotic workcells are currently operational in various sectors including manufacturing, consumer packaged goods, and food & beverage industries in the United States. The company offers its robotic workforce through a factory automation-as-a-service model, allowing customers to benefit from automation without upfront capital commitments. Rios has already established agreements with over a dozen customers in the U.S. and Japan, ranging from medium-sized enterprises to large corporations.
#
# It is important to note that Rios has a distributed workforce across the United States, in addition to a subsidiary located in Australia. The company's commitment to revolutionizing factory automation through cutting-edge technology and innovative business models has attracted significant attention from investors and industry stakeholders.
#
# In conclusion, Rios Intelligent Machines has successfully raised $28 million in Series A funding, which will undoubtedly fuel the company's efforts to further expand its presence in the factory automation sector and continue providing advanced AI-powered solutions to businesses worldwide.
#
# Source: Rios Intelligent Machines Raises $28M in Series A Funding - FinSMEs
#
# ---
#
# Overview, a San Francisco-based manufacturing automation company, recently secured $10 million in Series A funding. The funding round was spearheaded by prominent investors such as Blumberg Capital, GV, and Momenta, with additional support from Bain Capital. Founded by Chris Van Dyke and Austin Appel, Overview specializes in developing inspection systems powered by deep learning technologies. These systems cater to enterprises engaged in manufacturing various goods by assisting in the identification and elimination of defects on the production line.
#
# One of Overview's key offerings is the Snap Platform, a cloud-native computer vision technology. This platform streamlines operations by managing devices, facilitating algorithm development, and ensuring compatibility with standard cameras and production system software. The versatility of the Snap Platform allows it to seamlessly integrate with existing factory lines, providing customers with a scalable solution that aligns with their evolving business needs.
#
# Overall, Overview's innovative approach to leveraging deep learning technologies in manufacturing automation has attracted significant investor interest, as evidenced by the successful Series A funding round.
#
# Source: Overview Raises $10M in Series A Funding - FinSMEs // B63J // Deep Learning Machine Vision
#
# ---
# The text discusses the significant growth and potential of computer vision technology in the field of factory automation, particularly in the context of detecting anomalies during production processes. Computer vision, a subfield of AI, focuses on enabling computers to understand objects in images. According to a 2021 IDG survey, a substantial percentage of organizations are either planning to implement or investigating the implementation of computer vision technology. The market for computer vision is projected to grow significantly, reaching $17.4 billion by 2024 if the current trend continues.
#
# Manufacturing companies are increasingly interested in leveraging computer vision technology to enhance quality control and detect defects during production. Implementing AI-powered quality inspection systems can lead to a significant increase in productivity and defect detection rates compared to manual inspection methods. This technology has the potential to minimize tedious, expensive, and dangerous work in manufacturing processes.
#
# Several startups, including Overview, Landing AI, Cogniac, and Roboflow, are developing computer vision products tailored for manufacturing applications. Overview, founded in 2018 by former Tesla engineers, is designing a platform to help identify manufacturing defects on production lines. The company recently secured $10 million in funding to further develop its AI-powered visual inspection platform.
#
# Overview's technology integrates cameras, data, and algorithms to automate product inspection processes using customizable "stations." These stations can be controlled manually or run automatically, enabling users to inspect products at higher speeds and catalog shipments for damage disputes. The technology also allows for the creation of rules to trigger alerts and communications based on inspection results.
#
# Despite the potential benefits of computer vision technology in reducing manufacturing errors, its adoption has been relatively slow. Companies cite challenges such as infrastructure and operability, data quality, and transparency as key barriers to deploying computer vision systems across their organizations. However, Overview's innovative architecture aims to simplify the implementation process and appeal to manufacturing customers who may have been hesitant to adopt the technology previously.
#
# In conclusion, the text highlights the growing importance of computer vision technology in revolutionizing quality control processes in manufacturing. Overview's AI-powered visual inspection platform, along with similar technologies from other startups, has the potential to drive significant improvements in productivity, defect detection, and overall quality assurance in factory automation.
#
# Source: VentureBeat.
#
# ---
#
# ["The text discusses Aniai, a New York City-based robotic company and kitchen solutions provider, securing $12 million in Pre-Series A funding. The funding round was led by InterVest, with participation from SV Investment, Ignite Innovation, and Capstone Partners. Aniai plans to use the funds to establish its first manufacturing facility, Factory One, in South Korea. This move aims to ensure stable production and efficient supply chain management for its flagship product, the Alpha Grill. The company, founded in 2020 by CEO Gunpil Hwang, specializes in developing robotic solutions for cooking hamburgers. The Alpha Grill utilizes robotics to cook hamburgers, featuring a double-sided grill capable of cooking up to eight patties simultaneously or 200 patties per hour. This technology helps restaurant brands streamline operations by automating tasks like pressing and flipping patties, reducing cooking time, and easing the labor burden on employees.\n\nGunpil Hwang expressed that the funding will support Aniai's mission to enhance kitchen productivity through robotics and automation. The company plans to scale up production to meet current and future demand. Additionally, Aniai intends to enhance the capabilities of the Alpha Grill by integrating advanced, cloud-based AI software. This upgrade is expected to further improve the performance of the grill, benefiting both existing and new customers.\n\nIn conclusion, Aniai's successful funding round will enable the company to establish a manufacturing facility in South Korea, enhance production capabilities, and integrate advanced AI software into its flagship product, the Alpha Grill. This strategic move aligns with the company's goal of revolutionizing kitchen productivity through innovative robotic solutions.\n\nSource: Aniai Closes $12M Pre-Series A Funding", 'Virdee, a company based in Austin, Texas, specializing in guest experience technology and check-in automation, recently secured $12.4 million in Series A funding. The funding round was led by Moneta Ventures, with participation from Silverton Partners, Koch Real Estate Investments, Alumni Ventures, DJR Advisors, Capital Factory, and other partners. Brent Kelton, a Partner at Moneta Ventures, also joined Virdee\'s board as part of the funding agreement.\n\nThis investment brought Virdee\'s total funding amount to $21 million, following previous financial support from Silverton Partners in a Seed financing round in February 2022 and angel investment in 2020 led by Rajiv Trivedi, former President of La Quinta Inns & Suites. Founded in 2020 by Branigan Mulcahy and Nadav Cornberg, Virdee offers a software platform for the hospitality industry that enhances guest experiences and automates check-in processes through various digital channels such as web, app, kiosk, and SDK options.\n\nVirdee\'s platform leverages digital applications and AI to streamline front desk transactions, enabling hotels of all sizes to integrate their solution seamlessly and improve guest interactions. By offering contactless hotel check-in capabilities that are compatible with diverse systems, including web, app, and kiosk-based setups, Virdee\'s technology supports features like Virdee Identity, upgrades, upsells, and Remote Assistance, facilitating 100% of guest check-ins. The company\'s client base includes prominent casino hotels in Las Vegas and other major hotel brands, highlighting the effectiveness and versatility of Virdee\'s solutions in the hospitality sector.\n\nIn summary, Virdee\'s recent funding milestone underscores the growing recognition and adoption of its innovative guest experience technology and check-in automation platform within the hospitality industry. The company\'s strategic partnerships and expanding installation base further solidify its position as a leading provider of solutions that enhance guest satisfaction, streamline operations, and elevate overall hotel experiences.\n\nSource: "Virdee Closes $12.4M in Series A Funding" ...
#
# ----------------------------------------------
# ----------------------------------------------

# %%
Problem = """Based on the provided information, the problem with the highest overall rating is:
    - Problem: Lack of seamless integration and communication between different factory automation systems and equipment.
    - User Group Impacted: Factory automation engineers and operators.
    - Specific Pain Point: Inefficient workflows, increased downtime, and suboptimal performance due to manual intervention and lack of real-time data synchronization.
    - Summary of Selection Criteria: Large target group impacted, very relevant pain point to factory automation industry and users, specific and critical issue in the industry."""

print(Problem)
# Out:
# Based on the provided information, the problem with the highest overall rating is:
#     - Problem: Lack of seamless integration and communication between different factory automation systems and equipment.
#     - User Group Impacted: Factory automation engineers and operators.
#     - Specific Pain Point: Inefficient workflows, increased downtime, and suboptimal performance due to manual intervention and lack of real-time data synchronization.
#     - Summary of Selection Criteria: Large target group impacted, very relevant pain point to factory automation industry and users, specific and critical issue in the industry.

# %% [markdown]
# # Answering questions on the results with OpenAI GPT

# %%
import openai

openai.api_key = os.getenv('OPENAI_API_KEY') # Assign OpenAI API

#System prompt (for all users)
system_prompt = f"""You are part of a brainstorming session that wants to come up with a solution to a specific problem. You customer handed you the following problem:
       
        {Problem}
        
        Now you try to figure out a solution in a brainstorming session with the Walt Disney Method: 
        It is a tool for brainstorming ideas. It involves using 3 sequential roles, namely the Dreamer, the Realist, and the Critic.
        The Dreamer: you focus on free association and brainstorming of ideas. Anything goes here. It's your chance to let your imagination run wild! Be enthusiastic and approach the task with questions such as “What would be nice?”, “What would be the optimal situation?” or “What would I wish for?” Assume that everything is possible.
        The Realist: Be realistic and decide which of your ideas are actually possible or practical. What would you need to do in the real world in order to make them happen? Take a pragmatic approach and ask which materials, which knowledge, which techniques there are with which the thoughts of the dreamer can be realised.
        The Critic: Examine proposals and its real-world implications from a more critical viewpoint. You want to make sure that your plan is as comprehensive as it can be. Every detail needs to be scrutinized and refined. It is about identifying opportunities and risks, pointing out limits and gaps, and expressing constructive and always positive criticism. Try to identify possible sources of error.
        
        Your work is highly crucial and you are responsible of coming up with the next best innovation.
        """

#Dreamer prompt (idea: come up with crazy ideas)
dreamer_solutions = {}
i = 0

user_prompt = f"""
    Consider the text below, delimited by ```, in the area of {query}:
    ```
    {summary_list}
    ```    
  
    Imagine you are the Dreamer. 
    
    Take a deep breath and work on this problem step by step. 

    
    Please develop 5 really specific ideas/visions on how this problem can be solved. The solutions should consider the following points:
    - You can let your imagination run wild and you do not care about possible limitations. It's more important the idea is new then it can really work.  
    - They should not be too general. 
    - The solution should not already exist on the market and be novel. 
    - The ideas should not be too similar to each other
    
    For the solution, please write only 40 words. It should contain the following contents:
    1) Your solution in max 3 words (title)
    2) Your solution summarized in 1 sentence
    3) Your solution from the customer perspective (customer journey: how does it work for the customer) 
    4) Why the solution is kind of new (not existing on the market)
    5) Please provide some sources of inspiration that you used from the document excerpts.


    
    """
    
completion = openai.chat.completions.create(
        model="gpt-4-0125-preview",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        temperature=0.8,
        max_tokens=2000,
        top_p=0.95,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None
    )
print(completion.choices[0].message.content) # This prints the content of the output in a more readable way
print("\n---\n")  # This adds a separator between the messages for readability
dreamer_solutions[i] = completion.choices[0].message
i += 1


#Realist prompt (idea: evaluate if it is possible and what would be needed)
realist_solutions = {}

user_prompt1 = f"""

    Imagine you are the Realist. 
    
    Take a deep breath and work on this problem step by step. 

    
    Consider the following solutions: {dreamer_solutions}.
    
    Please give me the 3 clearly speperated pieces of information for each of the solutions (in total 50 words max):
    1) "Title": Repeat the titel of the idea
    2) "Summary": 3 sentence summary of the solution
    3) "Evaluation criteria 1 detail": What would you need to do in the real world in order to make the solution happen? Answer which knowledge, which techniques there are with which the solutions can be realised. Explain in 5 sentences. 
    4) "Evaluation criteria 1": Is the solution actually possible? Answer can be 1,2 or 3 (1 = not possible, 2 = maybe possible, 3 = possible) (be the most critical person ever. Only give max. 1 of the 3 solution a 3)

    """
    

completion = openai.chat.completions.create(
model="gpt-4-0125-preview",
messages=[
{"role": "system", "content": system_prompt},
{"role": "user", "content": user_prompt1}
],
temperature=0.7,
max_tokens=2000,
top_p=0.95,
frequency_penalty=0,
presence_penalty=0,
stop=None
)

    
print(completion.choices[0].message.content) # This prints the content of the output in a more readable way
print("\n---\n")  # This adds a separator between the messages for readability
realist_solutions[0] = completion.choices[0].message


#Critics prompt (idea: evaluate if there are a lot potential sources of error)
critics_solutions = {}

user_prompt2 = f"""

    Imagine you are the Critic. 
    
    Consider the following solutions: {realist_solutions}.
    
    Take a deep breath and work on this problem step by step. 
    
    Please give me the following 4 clearly seperated pieces of information for each solution (40 words in total):
    1) "Title": Repeat the titel of the idea
    2) "Summary": 3 sentence summary of the solution
    3) "Evaluation criteria 2 details": Identify possible sources of error. Look for risks, pointing out limits and gaps, and expressing constructive criticism. Examine its real-world implications from a more critical viewpoint. You want to make sure that your plan is as comprehensive as it can be. Every detail needs to be scrutinized and refined. (1 sentence only)
    4) "Evaluation criteria 2": Does it have many potential sources of errors? Answer can be 1,2 or 3 (1 = many sources of error, 2 = some sources of error, 3 = few sources of error) (be the most critical person ever. Only give max. 1 of the 3 solution a 3) (1 sentence)
    """
    

completion = openai.chat.completions.create(
model="gpt-4-0125-preview",
messages=[
{"role": "system", "content": system_prompt},
{"role": "user", "content": user_prompt2}
],
temperature=0.7,
max_tokens=2000,
top_p=0.95,
frequency_penalty=0,
presence_penalty=0,
stop=None
)

    
print(completion.choices[0].message.content) # This prints the content of the output in a more readable way
print("\n---\n")  # This adds a separator between the messages for readability
critics_solutions[0] = completion.choices[0].message


#Summary

summary_solutions = {}

user_prompt3 = f"""

    Imagine you should give a summary to a high executive manager about a brainstorming session. 
    
    During the brainstorming session your team came up with the following ideas: {dreamer_solutions}. 
    For each idea you considered how feasible it is {realist_solutions}. 
    Last, you evaluated the amount of potential sources of errors: {critics_solutions} 
    
    Take a deep breath and work on this problem. 
    
    Please summarize in one paragraph for each solution, with the following content:
    
    “Name”: Solution name (5 words max)
    “Solved Problem”: 3-sentence summary of the problem that is being solved 
    “Solution”: Provide a short summary of the solution and how it works (in 4 to 5 sentences)
    “Impact”: How does the solution solve the specific problem (2-3 sentences)
    “Technology”: Please also give a very detailed explanation of which technology is utilized and how it is utilized. Please be very diligent in this task, imagine you are explaining it to the CTO who has a background of engineering and has to implement the solution  (4-5 sentences)
    “Sources”: Please provide the specific sources of inspiration that you used from the {summary_list} (1 sentence max)
    
    """
    

completion = openai.chat.completions.create(
model="gpt-4-0125-preview",
messages=[
{"role": "system", "content": system_prompt},
{"role": "user", "content": user_prompt3}
],
temperature=0.7,
max_tokens=2000,
top_p=0.95,
frequency_penalty=0,
presence_penalty=0,
stop=None
)

    
print(completion.choices[0].message.content) # This prints the content of the output in a more readable way
print("\n---\n")  # This adds a separator between the messages for readability
summary_solutions[0] = completion.choices[0].message
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nt/p2r023612c74fk40qrw64s6m0000gn/T/ipykernel_52250/4070628249.py in <module>
#       6 system_prompt = f"""You are part of a brainstorming session that wants to come up with a solution to a specific problem. You customer handed you the following problem:
#       7
# ----> 8         {Problem}
#       9
#      10         Now you try to figure out a solution in a brainstorming session with the Walt Disney Method:
#
# NameError: name 'Problem' is not defined

# %%
# Initial rating of the solutions

initial_rating = {}

system_prompt_2 = f"""You are a highly qualified critical rater of business opportunities. You are now tasked to evaluate a set of opportunities with the following problem in mind: {Problem} """


user_prompt4 = f""""

Please take all solutions from the following text: {summary_solutions}
First, repeat the following points for the first solution:
    - "Name"
    - “Solved Problem”
    - “Solution”
    - “Impact”
    - “Technology”
    - “Sources”

Then, rate the first solution according to the following criteria. Please justify your ratings in max one sentence. Please be very critical in your ratings and only give a 3 out of 3 rating when it is very good:   

    - Functionality and Performance: Assess whether the solution addresses and solves the problem it’s supposed to solve. This includes estimating if the solution can solve the problem quickly and effectively. (1 = low performance, 2 = medium performance, 3 = high performance)
    - Scalability: Evaluate whether the solution can adapt to future growth (or shrinking) of demand and accommodate changes in requirements: How flexible is the solution? (1 = low scalability, 2 = medium scalability, 3 = high scalability)
    - Cost-effectiveness: Assess the costs associated with the solution. How large are upfront costs for implementation such as training, facilities, machines, etc.? How large are operating costs such as personnel, energy, maintenance, etc.? The solution should have a relatively high return on investment. (1 = low cost-effectiveness, 2 = medium cost-effectiveness 3 = high cost-effectiveness)
    - Innovativeness: How innovative is the solution? Do similar solutions for the problem exist already? (1 = low innovativeness, 2 = medium innovativeness 3 = high innovativeness)
    - Uniqueness: The solutions contained in the list should differ substantially and not be similar. (1 = low uniqueness, 2 = medium uniqueness 3 = high uniqueness)
    - Overall Rating: Sum of all the previous ratings, out of 15

Now, repeat these steps for all solutions.

"""


completion = openai.chat.completions.create(
model="gpt-4-0125-preview",
messages=[
{"role": "system", "content": system_prompt_2},
{"role": "user", "content": user_prompt4}
],
temperature=0.7,
max_tokens=2000,
top_p=0.95,
frequency_penalty=0,
presence_penalty=0,
stop=None
)

print(completion.choices[0].message.content) # This prints the content of the output in a more readable way
print("\n---\n")  # This adds a separator between the messages for readability
initial_rating[0] = completion.choices[0].message
# Out:
# **Name**: Universal Automation Language (UAL)
#
# **Solved Problem**: This solution addresses the challenge of integrating diverse factory automation systems due to incompatible programming languages.
#
# **Solution**: UAL proposes a universal programming language designed for all factory automation systems, enabling engineers to write code once, which is then translated into the specific languages of various equipment and systems.
#
# **Impact**: By standardizing the programming language across different systems, UAL minimizes the need for manual intervention and reduces the likelihood of errors during the integration process.
#
# **Technology**: The development of UAL would involve research into existing automation languages and protocols, followed by the creation of a comprehensive language that encompasses these systems' functionalities.
#
# **Sources**: Inspired by interoperability challenges and integration efforts across companies like Aniai and Terabase Energy.
#
# ### Ratings for UAL
#
# - **Functionality and Performance**: 3. UAL directly addresses the core issue of incompatible programming languages, promising to significantly enhance system integration and operational efficiency.
#
# - **Scalability**: 3. The solution's design inherently supports scalability, as a universal language can adapt to new systems and technologies, allowing for future growth.
#
# - **Cost-effectiveness**: 2. While UAL could offer long-term savings by reducing integration efforts, the initial development, standardization, and adoption processes could be costly and time-consuming.
#
# - **Innovativeness**: 3. Introducing a universal programming language for factory automation is a highly innovative approach that could revolutionize system interoperability.
#
# - **Uniqueness**: 3. The concept of a universal automation language is unique and does not have direct existing counterparts in the industry.
#
# - **Overall Rating**: 14/15
#
# ---
#
# **Name**: Real-Time Integration Mesh (RTIM)
#
# **Solved Problem**: Eliminates the inefficiency caused by the lack of real-time communication between different automation systems.
#
# **Solution**: RTIM is a self-updating, dynamic network that connects various automation systems in real-time, allowing for integrated systems management via a single dashboard.
#
# **Impact**: The implementation of RTIM drastically reduces the time and effort required to manage multiple automation systems.
#
# **Technology**: Implementing RTIM would require advanced networking technologies and a robust, secure, and scalable infrastructure.
#
# **Sources**: Drawing on advancements in cloud-based AI software by Aniai and digital automation solutions by Terabase Energy.
#
# ### Ratings for RTIM
#
# - **Functionality and Performance**: 3. RTIM directly tackles the issue of real-time communication, which is crucial for efficient system integration and management.
#
# - **Scalability**: 3. Its mesh network approach allows for easy scalability, accommodating additional systems without significant reconfiguration.
#
# - **Cost-effectiveness**: 2. While potentially offering significant operational efficiencies, the complexity of creating and maintaining a dynamic network could entail high initial and ongoing costs.
#
# - **Innovativeness**: 2. Dynamic networking and real-time integration are not entirely new concepts, but applying them in this context is relatively innovative.
#
# - **Uniqueness**: 2. Similar real-time integration solutions may exist, but the specific approach and focus on factory automation systems provide some degree of uniqueness.
#
# - **Overall Rating**: 12/15
#
# ---
#
# **Name**: Cognitive Automation Orchestrator (CAO)
#
# **Solved Problem**: Streamlines workflow paths across different systems, optimizing operational efficiency.
#
# **Solution**: CAO uses AI to predict and orchestrate the most efficient workflow paths, dynamically adjusting operations in real-time.
#
# **Impact**: By optimizing workflows, CAO significantly reduces operational inefficiencies and enhances system adaptability.
#
# **Technology**: CAO requires sophisticated AI algorithms and machine learning components integrated with factory systems.
#
# **Sources**: Concept inspired by AI advancements in solutions by Aniai and Terabase Energy.
#
# ### Ratings for CAO
#
# - **Functionality and Performance**: 3. CAO directly addresses workflow inefficiencies with an AI-driven approach, promising significant improvements in operational efficiency.
#
# - **Scalability**: 2. While AI models can adapt and scale, integrating and scaling CAO across diverse systems with different capabilities might present challenges.
#
# - **Cost-effectiveness**: 2. AI development and integration are costly, but the potential operational savings could justify the investment.
#
# - **Innovativeness**: 3. Leveraging AI to dynamically optimize workflows in factory automation is a highly innovative and cutting-edge approach.
#
# - **Uniqueness**: 2. Although AI is increasingly used in various sectors, its specific application for orchestrating factory automation workflows adds a degree of uniqueness.
#
# - **Overall Rating**: 12/15
#
# ---
#
# **Name**: Quantum Computing Interface (QCI)
#
# **Solved Problem**: Addresses the challenge of real-time data processing and integration in complex factory environments.
#
# **Solution**: QCI uses quantum computing for rapid data processing and integration, enabling immediate decision-making across systems.
#
# **Impact**: Quantum computing introduces a new level of performance, significantly improving real-time automation system management.
#
# **Technology**: Developing QCI involves research into quantum computing and the creation of quantum-safe protocols and hardware.
#
# **Sources**: Inspired by technological innovation and research by companies like Cellares and Worlds Enterprises.
#
# ### Ratings for QCI
#
# - **Functionality and Performance**: 2. While promising, quantum computing's current technological maturity may not yet fully support its envisioned application in factory automation.
#
# - **Scalability**: 1. Quantum computing faces significant scalability and stability challenges that could hinder its practical application in the near term.
#
# - **Cost-effectiveness**: 1. The high cost of quantum computing research, development, and implementation makes it less cost-effective at this stage.
#
# - **Innovativeness**: 3. Applying quantum computing to factory automation is highly innovative, representing a significant technological leap forward.
#
# - **Uniqueness**: 3. This approach is highly unique, with no direct counterparts currently available in the industrial automation sector.
#
# - **Overall Rating**: 10/15
#
# ---
#
# **Name**: Augmented Reality Configurator (ARC)
#
# **Solved Problem**: Facilitates the physical integration planning of automation systems in a tangible and interactive manner.
#
# **Solution**: ARC uses AR technology to allow operators to visualize and configure system integration in real-time.
#
# **Impact**: ARC simplifies system integration planning, reducing complexity and enhancing operational efficiency.
#
# **Technology**: ARC requires advancements in AR technology and software that can accurately represent and integrate automation systems.
#
# **Sources**: Inspired by AI-based automation and digital solutions advancements by companies like Worlds Enterprises and Terabase Energy.
#
# ### Ratings for ARC
#
# - **Functionality and Performance**: 2. ARC offers a novel approach to system integration planning, but its effectiveness depends heavily on the accuracy and usability of the AR technology.
#
# - **Scalability**: 2. While AR technology can be scalable, the solution's effectiveness across different scales of factory operations may vary.
#
# - **Cost-effectiveness**: 2. Initial costs for AR technology development and deployment could be high, but potential operational efficiencies may justify the expense.
#
# - **Innovativeness**: 2. Using AR for system integration planning is innovative, though AR itself is being explored in various sectors.
#
# - **Uniqueness**: 2. ARC's application of AR in this context is relatively unique, though AR technology is increasingly common in industrial applications.
#
# - **Overall Rating**: 10/15
#
# ---

# %%
user_prompt5 = f""""

Please take all the solutions and the corresponding ratings from: {initial_rating}

Take the three solutions with the highest overall rating out of 15, sorting them in descending rating order.

Outline the following points for these solution from the following text: {summary_solutions}:
    - "Name"
    - “Solved Problem”
    - “Solution”
    - “Impact”
    - “Technology”
    - “Sources”


"""


completion = openai.chat.completions.create(
model="gpt-4-0125-preview",
messages=[
{"role": "system", "content": system_prompt_2},
{"role": "user", "content": user_prompt5}
],
temperature=0.7,
max_tokens=2000,
top_p=0.95,
frequency_penalty=0,
presence_penalty=0,
stop=None
)

print(completion.choices[0].message.content) # This prints the content of the output in a more readable way
print("\n---\n")  # This adds a separator between the messages for readability
# Out:
# ### 1. Universal Automation Language (UAL)
#
# - **Name**: Universal Automation Language (UAL)
# - **Solved Problem**: This solution addresses the challenge of integrating diverse factory automation systems due to incompatible programming languages.
# - **Solution**: UAL proposes a universal programming language designed for all factory automation systems, enabling engineers to write code once, which is then translated into the specific languages of various equipment and systems. It aims to create a seamless bridge between the myriad of languages and protocols currently in use, facilitating easier and more efficient interoperability among different automation technologies. The end goal is to significantly reduce the time and effort required for system integration and to enhance operational efficiency.
# - **Impact**: By standardizing the programming language across different systems, UAL minimizes the need for manual intervention and reduces the likelihood of errors during the integration process. This leads to more streamlined workflows, reduced downtime, and improved overall performance of factory automation systems.
# - **Technology**: The development of UAL would involve in-depth research into existing automation languages and protocols, followed by the creation of a comprehensive language that encompasses the functionalities of these diverse systems. This would require collaboration with equipment manufacturers for adoption and continuous updates to ensure compatibility with new technologies. The technology behind UAL would likely leverage compilers or interpreters capable of translating UAL code into the native commands of each targeted automation system, thus ensuring seamless interoperability.
# - **Sources**: Inspired by interoperability challenges and integration efforts across companies like Aniai and Terabase Energy.
#
# ### 2. Real-Time Integration Mesh (RTIM)
#
# - **Name**: Real-Time Integration Mesh (RTIM)
# - **Solved Problem**: Eliminates the inefficiency caused by the lack of real-time communication between different automation systems.
# - **Solution**: RTIM is envisioned as a self-updating, dynamic network that connects various automation systems in real-time, allowing operators to manage and control integrated systems via a single dashboard. This mesh network approach ensures that changes in one system are automatically and instantly reflected across all connected systems, thus maintaining synchronization without manual intervention. The aim is to provide a unified platform that simplifies the monitoring and management of complex factory automation environments.
# - **Impact**: The implementation of RTIM drastically reduces the time and effort required to manage multiple automation systems, leading to significant improvements in operational efficiency and a reduction in system downtime.
# - **Technology**: Implementing RTIM would require the development of advanced networking technologies capable of handling high volumes of real-time data transmission between different systems. This involves creating a robust, secure, and scalable infrastructure that supports dynamic updates and integrates seamlessly with existing automation systems. The underlying technology would likely include real-time data processing algorithms and a user-friendly interface for the dashboard, all designed to ensure reliable and instantaneous communication across the network.
# - **Sources**: Drawing on advancements in cloud-based AI software by Aniai and digital automation solutions by Terabase Energy.
#
# ### 3. Cognitive Automation Orchestrator (CAO)
#
# - **Name**: Cognitive Automation Orchestrator (CAO)
# - **Solved Problem**: Streamlines workflow paths across different systems, optimizing operational efficiency.
# - **Solution**: The CAO functions as an AI-driven tool that predicts and orchestrates the most efficient workflow paths through various automation systems. Factory operators input desired outcomes, and the CAO uses its predictive capabilities to suggest and implement the optimal paths to achieve these goals. This tool is designed to dynamically adjust operations across different systems in real-time, thereby maximizing efficiency and minimizing manual oversight.
# - **Impact**: By leveraging AI to optimize workflows, CAO significantly reduces operational inefficiencies and enhances the adaptability of automation systems to changing conditions, leading to improved performance and productivity.
# - **Technology**: CAO's implementation would require the creation of sophisticated AI algorithms capable of analyzing vast amounts of data to understand and optimize complex workflows. These algorithms would need to be integrated with existing factory systems, ensuring seamless communication and operation. The technology would also include machine learning components to continually improve workflow predictions based on operational data, making the system increasingly efficient over time.
# - **Sources**: Concept inspired by AI advancements in solutions by Aniai and Terabase Energy.
#
# ---
